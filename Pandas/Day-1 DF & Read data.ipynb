# %%
import pandas as pd

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in /opt/anaconda3/lib/python3.11/site-packages (2.1.4)
# Requirement already satisfied: numpy<2,>=1.23.2 in /opt/anaconda3/lib/python3.11/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.11/site-packages (from pandas) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /opt/anaconda3/lib/python3.11/site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
csv
excel
dict
json
api
html
SQL

# %%
import pandas as pd

# %%
ls
# Out:
# 3006.csv              Day-1.ipynb           demo.json
# Booth Analysis .xlsx  coffee.csv            shubham-photo/

# %%
df = pd.read_csv('3006.csv')

# %%
emp = {
    'id':[1,2,3,4],
    'name':['shubham','rahul','234','54tr'],
    'sal':[589594,'cv','dfg','dfg']
     
}

# %%
df = pd.DataFrame(emp)

# %%
df
# Out:
#    id     name     sal
# 0   1  shubham  589594
# 1   2    rahul      cv
# 2   3      234     dfg
# 3   4     54tr     dfg

# %%
df = pd.read_excel('Booth Analysis .xlsx',sheet_name='Table 1')

# %%
df.head()
# Out:
#    Polling Booth N Polling Booth N.1 Parent Constitu Winner- 2014  \
# 0                1            Wadala           Ashti          BJP
# 1                2         Vardhapur           Ashti          BJP
# 2                3        Sattarapur           Ashti          BJP
# 3                4           Pilapur           Ashti          BJP
# 4                5      Belora (bu )           Ashti          INC
#
#    1st Runner up o  Margin (%)  Margin  Unnamed: 7  Total Voters  BJP - Votes  \
# 0              NaN    0.204499     NaN         1.0           489          220
# 1              NaN    4.000000     NaN        17.0           425          210
# 2              NaN    5.204461     NaN        14.0           269          136
# 3              NaN    4.336735     NaN        17.0           392          196
# 4              NaN    9.042553     NaN        68.0           752          322
#
#    ...  Margin %  Margin.1  Unnamed: 18  Total Voters.1  BJP- Votes  \
# 0  ...  4.819277       NaN         24.0             498         NaN
# 1  ...  7.294118       NaN         31.0             425         NaN
# 2  ...  9.219858       NaN         26.0             282         NaN
# 3  ...  7.333333       NaN         33.0             450         NaN
# 4  ...  5.779570       NaN         43.0             744         NaN
#
#   Unnamed: 21  BJP- % votes  INC- Votes.1  Unnamed: 24  INC- % Votes
# 0       225.0     45.180723           NaN        249.0     50.000000
# 1       221.0     52.000000           NaN        190.0     44.705882
# 2       122.0     43.262411           NaN        148.0     52.482270
# 3       236.0     52.444444           NaN        203.0     45.111111
# 4       357.0     47.983871           NaN        314.0     42.204301
#
# [5 rows x 26 columns]

# %%
df = pd.read_excel('Booth Analysis .xlsx',sheet_name= 'Sheet1')

# %%
sheet_name = ['Table 1','Sheet1','Sheet2','Sheet3','Sheet4']   #should be dynamic

df_list = []


for sheet in sheet_name:
    df_list.append(pd.read_excel('Booth Analysis .xlsx',sheet_name=sheet))
    
final_df = pd.concat(df_list)

# %%
final_df.describe()
# Out:
#        Polling Booth N  1st Runner up   Margin (%)      Margin  Unnamed: 7  \
# count        39.000000             0.0   39.000000   28.000000   11.000000
# mean         20.000000             NaN   10.621682   58.178571   43.000000
# std          11.401754             NaN   12.388724   54.887126   32.811583
# min           1.000000             NaN    0.204499    2.000000    1.000000
# 25%          10.500000             NaN    4.420284   19.500000   17.000000
# 50%          20.000000             NaN    6.682578   46.000000   30.000000
# 75%          29.500000             NaN   12.376258   65.250000   71.000000
# max          39.000000             NaN   70.606061  233.000000  103.000000
#
#        Total Voters  BJP - Votes  BJP- % vote  INC- Votes  Unnamed: 12  ...  \
# count     39.000000    39.000000    39.000000   28.000000    11.000000  ...
# mean     547.128205   258.692308    48.052413  254.107143   223.818182  ...
# std      158.677790    70.580359     8.496873   89.716979    76.106265  ...
# min      237.000000    83.000000    29.856115   47.000000   122.000000  ...
# 25%      416.000000   215.000000    43.959617  186.750000   184.000000  ...
# 50%      584.000000   269.000000    48.387097  266.000000   200.000000  ...
# 75%      689.000000   304.000000    50.338476  292.000000   261.500000  ...
# max      811.000000   389.000000    84.848485  450.000000   390.000000  ...
#
#        32.42909988         274  33.78545006  1.909307876         16  \
# count     8.000000    8.000000     8.000000     8.000000   8.000000
# mean     45.658675  306.500000    48.537797     6.786360  43.000000
# std       5.535656   87.318792     6.173674     5.003193  29.784943
# min      36.363636  182.000000    42.673522     2.635432  17.000000
# 25%      41.037414  253.000000    43.779981     3.266944  18.750000
# 50%      48.913906  309.500000    48.300688     5.001478  32.500000
# 75%      49.752475  355.250000    49.750912     7.968677  60.500000
# max      50.119332  450.000000    61.983471    16.666667  93.000000
#
#               838         401  47.85202864         385  45.94272076
# count    8.000000    8.000000     8.000000    8.000000     8.000000
# mean   643.000000  297.375000    46.261895  300.375000    45.894772
# std    146.267856   74.670586     5.964181   96.739617     5.082993
# min    423.000000  166.000000    38.961039  182.000000    39.393939
# 25%    566.250000  254.250000    41.637798  240.000000    42.958172
# 50%    649.500000  307.500000    46.706241  288.500000    44.936940
# 75%    759.000000  343.000000    49.121865  364.000000    47.428220
# max    827.000000  389.000000    56.060606  434.000000    54.358974
#
# [8 rows x 87 columns]

# %%
# !pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in /opt/anaconda3/lib/python3.11/site-packages (3.0.10)
# Requirement already satisfied: et_xmlfile in /opt/anaconda3/lib/python3.11/site-packages (from openpyxl) (1.1.0)

# %%
from openpyxl import load_workbook

# %%
wb = load_workbook(filename='Booth Analysis .xlsx')
wb = wb.sheetnames

# %%
wb
# Out:
# ['Table 1', 'Sheet1', 'Sheet2', 'Sheet3', 'Sheet4']

# %%
sheet_name = wb
df_list = []


for sheet in sheet_name:
    df_list.append(pd.read_excel('Booth Analysis .xlsx',sheet_name=sheet))
    
final_df = pd.concat(df_list)

# %%
final_df.head(5)
# Out:
#    Polling Booth N Polling Booth N.1 Parent Constitu Winner- 2014  \
# 0                1            Wadala           Ashti          BJP
# 1                2         Vardhapur           Ashti          BJP
# 2                3        Sattarapur           Ashti          BJP
# 3                4           Pilapur           Ashti          BJP
# 4                5      Belora (bu )           Ashti          INC
#
#    1st Runner up   Margin (%)  Margin  Unnamed: 7  Total Voters  BJP - Votes  \
# 0             NaN    0.204499     NaN         1.0           489          220
# 1             NaN    4.000000     NaN        17.0           425          210
# 2             NaN    5.204461     NaN        14.0           269          136
# 3             NaN    4.336735     NaN        17.0           392          196
# 4             NaN    9.042553     NaN        68.0           752          322
#
#    ...  Margin %  Margin.1  Unnamed: 18  Total Voters.1  BJP- Votes  \
# 0  ...  4.819277       NaN         24.0             498         NaN
# 1  ...  7.294118       NaN         31.0             425         NaN
# 2  ...  9.219858       NaN         26.0             282         NaN
# 3  ...  7.333333       NaN         33.0             450         NaN
# 4  ...  5.779570       NaN         43.0             744         NaN
#
#   Unnamed: 21  BJP- % votes  INC- Votes.1  Unnamed: 24  INC- % Votes
# 0       225.0     45.180723           NaN        249.0     50.000000
# 1       221.0     52.000000           NaN        190.0     44.705882
# 2       122.0     43.262411           NaN        148.0     52.482270
# 3       236.0     52.444444           NaN        203.0     45.111111
# 4       357.0     47.983871           NaN        314.0     42.204301
#
# [5 rows x 26 columns]

# %%
import requests

# %%
data = requests.get('https://reqres.in/api/users?page=2').content
data

# %%
import json

# %%
dict_data = json.loads(data)
dict_data

# %%
output = pd.DataFrame(dict_data['data'])

# %%
output.tail(40)
# Out:
#    id                       email first_name last_name  \
# 0   7    michael.lawson@reqres.in    Michael    Lawson
# 1   8  lindsay.ferguson@reqres.in    Lindsay  Ferguson
# 2   9      tobias.funke@reqres.in     Tobias     Funke
# 3  10      byron.fields@reqres.in      Byron    Fields
# 4  11    george.edwards@reqres.in     George   Edwards
# 5  12     rachel.howell@reqres.in     Rachel    Howell
#
#                                      avatar
# 0   https://reqres.in/img/faces/7-image.jpg
# 1   https://reqres.in/img/faces/8-image.jpg
# 2   https://reqres.in/img/faces/9-image.jpg
# 3  https://reqres.in/img/faces/10-image.jpg
# 4  https://reqres.in/img/faces/11-image.jpg
# 5  https://reqres.in/img/faces/12-image.jpg

# %%
data = requests.get('https://api.sampleapis.com/wines/reds').content
data

# %%
import json

# %%
data_dict =json.loads(data)
data_dict

# %%
df = pd.DataFrame(data_dict)

# %%
photo_col = df['image']

# %%
import os
import requests

folder_name = 'shubham-photo'

if not os.path.exists(folder_name):
    os.makedirs(folder_name)
    
for i,url in enumerate(photo_col):
    response = requests.get(url)
    if response.status_code == 200:
        with open(os.path.join(folder_name, f'image_{i+1}.png'),'wb') as file:
            file.write(response.content)
         print(f'Successfully downloaded image_{i+1}.png')
              
    else:
        print(f"failed to download {url}")

# %%
from openpyxl import load_workbook

# %%
data = load_workbook('Booth Analysis .xlsx')

sheet_name = data.sheetnames

data = []

for sheet in sheet_name:
    temp = pd.read_excel('Booth Analysis .xlsx',sheet_name=sheet)
    data.append(temp)

# %%
df = pd.concat(data)

# %%
df
# Out:
#     Polling Booth N Polling Booth N.1 Parent Constitu Winner- 2014  \
# 0                 1            Wadala           Ashti          BJP
# 1                 2         Vardhapur           Ashti          BJP
# 2                 3        Sattarapur           Ashti          BJP
# 3                 4           Pilapur           Ashti          BJP
# 4                 5      Belora (bu )           Ashti          INC
# ..              ...               ...             ...          ...
# 4                35    Peth Ahamadapu           Ashti          INC
# 5                36          Kinnhala           Ashti          INC
# 6                37         Dalpatpur           Ashti          BJP
# 7                38          Sirasoli           Ashti          BJP
# 8                39   Khadaki Booth N           Ashti          BJP
#
#     1st Runner up   Margin (%)  Margin  Unnamed: 7  Total Voters  BJP - Votes  \
# 0              NaN    0.204499     NaN         1.0           489          220
# 1              NaN    4.000000     NaN        17.0           425          210
# 2              NaN    5.204461     NaN        14.0           269          136
# 3              NaN    4.336735     NaN        17.0           392          196
# 4              NaN    9.042553     NaN        68.0           752          322
# ..             ...         ...     ...         ...           ...          ...
# 4              NaN   25.619835   186.0         NaN           726          264
# 5              NaN    0.339559     2.0         NaN           589          285
# 6              NaN    1.565996     7.0         NaN           447          221
# 7              NaN    7.326478    57.0         NaN           778          389
# 8              NaN    6.682578    28.0         NaN           419          210
#
#     ...   Margin %  Margin.1  Unnamed: 18  Total Voters.1  BJP- Votes  \
# 0   ...   4.819277       NaN         24.0             498         NaN
# 1   ...   7.294118       NaN         31.0             425         NaN
# 2   ...   9.219858       NaN         26.0             282         NaN
# 3   ...   7.333333       NaN         33.0             450         NaN
# 4   ...   5.779570       NaN         43.0             744         NaN
# ..  ...        ...       ...          ...             ...         ...
# 4   ...  11.923077      93.0          NaN             780       331.0
# 5   ...   3.327787      20.0          NaN             601       290.0
# 6   ...   4.018913      17.0          NaN             423       166.0
# 7   ...   6.650544      55.0          NaN             827       379.0
# 8   ...  16.666667      77.0          NaN             462       259.0
#
#    Unnamed: 21  BJP- % votes  INC- Votes.1  Unnamed: 24  INC- % Votes
# 0        225.0     45.180723           NaN        249.0     50.000000
# 1        221.0     52.000000           NaN        190.0     44.705882
# 2        122.0     43.262411           NaN        148.0     52.482270
# 3        236.0     52.444444           NaN        203.0     45.111111
# 4        357.0     47.983871           NaN        314.0     42.204301
# ..         ...           ...           ...          ...           ...
# 4          NaN     42.435897         424.0          NaN     54.358974
# 5          NaN     48.252912         270.0          NaN     44.925125
# 6          NaN     39.243499         183.0          NaN     43.262411
# 7          NaN     45.828295         434.0          NaN     52.478839
# 8          NaN     56.060606         182.0          NaN     39.393939
#
# [69 rows x 26 columns]

# %%
jsondata = '''{
    "winery": "Maselva",
    "wine": "Emporda 2012",
    "rating": {
        "average": "4.9",
        "reviews": "88 ratings"
    },
    "location": "Spain\n·\nEmpordà",
    "image": "https://images.vivino.com/thumbs/ApnIiXjcT5Kc33OHgNb9dA_375x500.jpg",
    "id": 1
}'''

with open('demo.json','w') as fp:
    fp.write(jsondata)

# %%
data = pd.read_json('demo.json')

# %%
data
# Out:
#           winery          wine      rating           location  \
# average  Maselva  Emporda 2012         4.9  Spain\n·\nEmpordà
# reviews  Maselva  Emporda 2012  88 ratings  Spain\n·\nEmpordà
#
#                                                      image  id
# average  https://images.vivino.com/thumbs/ApnIiXjcT5Kc3...   1
# reviews  https://images.vivino.com/thumbs/ApnIiXjcT5Kc3...   1

# %%
ls
# Out:
# 3006.csv              Untitled.ipynb        images/
# Booth Analysis .xlsx  demo.json             shubham-photo/

# %%
data = pd.read_csv('3006.csv')

# %%
data
# Out:
#         Id         Created At     Unique Id           Username    Status  \
# 0        1   10-04-2024 03:29   WP-88195426   demo11@gmail.com   pending
# 1        2   10-04-2024 03:29   WP-88195426   demo11@gmail.com   pending
# 2        3   10-04-2024 03:29   WP-88195426   demo11@gmail.com   pending
# 3        4   10-04-2024 03:29   WP-88195426   demo11@gmail.com   pending
# 4        5   10-04-2024 03:29   WP-88195426   demo11@gmail.com   pending
# ...    ...                ...           ...                ...       ...
# 3057  3058   10-04-2024 03:29   WP-88195426   demo11@gmail.com   pending
# 3058  3059   10-04-2024 03:29   WP-88195426   demo11@gmail.com   pending
# 3059  3060   10-04-2024 03:29   WP-88195426   demo11@gmail.com   pending
# 3060  3061   10-04-2024 03:29   WP-88195426   demo11@gmail.com   pending
# 3061  3062   10-04-2024 03:29   WP-88195426   demo11@gmail.com   pending
#
#          MobileNo
# 0      9049675396
# 1      9833248186
# 2      9970044614
# 3      9860007733
# 4      9049613752
# ...           ...
# 3057   9971586888
# 3058   8827219265
# 3059   9935266466
# 3060   9045851221
# 3061   9045408260
#
# [3062 rows x 6 columns]

# %%
data[12]
# Out:
#                                             Unnamed: 0  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 235                                                NaN
# 236                                                NaN
# 237                                                NaN
# 238                                                NaN
# 239  .mw-parser-output .reflist{font-size:90%;margi...
#
#                                                Country  \
# 0                                             World[a]
# 1                                                 Peru
# 2                                             Bulgaria
# 3                                      North Macedonia
# 4                               Bosnia and Herzegovina
# ..                                                 ...
# 235                                               Niue
# 236                                       Turkmenistan
# 237                                       Vatican City
# 238                                            Tokelau
# 239  .mw-parser-output .reflist{font-size:90%;margi...
#
#                                       Deaths / million  \
# 0                                                  867
# 1                                                 6455
# 2                                                 5728
# 3                                                 5473
# 4                                                 5181
# ..                                                 ...
# 235                                                  —
# 236                                                  —
# 237                                                  —
# 238                                                  —
# 239  .mw-parser-output .reflist{font-size:90%;margi...
#
#                                                 Deaths  \
# 0                                              7054080
# 1                                               220975
# 2                                                38700
# 3                                                 9977
# 4                                                16390
# ..                                                 ...
# 235                                                  —
# 236                                                  0
# 237                                                  0
# 238                                                  0
# 239  .mw-parser-output .reflist{font-size:90%;margi...
#
#                                                  Cases
# 0                                            775685948
# 1                                              4526977
# 2                                              1329519
# 3                                               350670
# 4                                               403659
# ..                                                 ...
# 235                                               1074
# 236                                                  0
# 237                                                 26
# 238                                                 80
# 239  .mw-parser-output .reflist{font-size:90%;margi...
#
# [240 rows x 5 columns]

# %%
data = pd.read_json('https://api.sampleapis.com/coffee/hot')
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /var/folders/28/xzg4vjpj3gj6x32fqvxyzd440000gn/T/ipykernel_3263/3923278419.py in <module>
# ----> 1 data = pd.read_json('https://api.sampleapis.com/coffee/hot')
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     205                 else:
#     206                     kwargs[new_arg_name] = new_arg_value
# --> 207             return func(*args, **kwargs)
#     208
#     209         return cast(F, wrapper)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/json/_json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options)
#     588         convert_axes = True
#     589
# --> 590     json_reader = JsonReader(
#     591         path_or_buf,
#     592         orient=orient,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/json/_json.py in __init__(self, filepath_or_buffer, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression, nrows, storage_options, encoding_errors)
#     673                 raise ValueError("nrows can only be passed if lines=True")
#     674
# --> 675         data = self._get_data_from_filepath(filepath_or_buffer)
#     676         self.data = self._preprocess_data(data)
#     677
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/json/_json.py in _get_data_from_filepath(self, filepath_or_buffer)
#     710             or file_exists(filepath_or_buffer)
#     711         ):
# --> 712             self.handles = get_handle(
#     713                 filepath_or_buffer,
#     714                 "r",
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     607
#     608     # open URLs
# --> 609     ioargs = _get_filepath_or_buffer(
#     610         path_or_buf,
#     611         encoding=encoding,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/common.py in _get_filepath_or_buffer(filepath_or_buffer, encoding, compression, mode, storage_options)
#     310         # assuming storage_options is to be interpreted as headers
#     311         req_info = urllib.request.Request(filepath_or_buffer, headers=storage_options)
# --> 312         with urlopen(req_info) as req:
#     313             content_encoding = req.headers.get("Content-Encoding", None)
#     314             if content_encoding == "gzip":
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/common.py in urlopen(*args, **kwargs)
#     210     import urllib.request
#     211
# --> 212     return urllib.request.urlopen(*args, **kwargs)
#     213
#     214
#
# ~/opt/anaconda3/lib/python3.9/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     212     else:
#     213         opener = _opener
# --> 214     return opener.open(url, data, timeout)
#     215
#     216 def install_opener(opener):
#
# ~/opt/anaconda3/lib/python3.9/urllib/request.py in open(self, fullurl, data, timeout)
#     521         for processor in self.process_response.get(protocol, []):
#     522             meth = getattr(processor, meth_name)
# --> 523             response = meth(req, response)
#     524
#     525         return response
#
# ~/opt/anaconda3/lib/python3.9/urllib/request.py in http_response(self, request, response)
#     630         # request was successfully received, understood, and accepted.
#     631         if not (200 <= code < 300):
# --> 632             response = self.parent.error(
#     633                 'http', request, response, code, msg, hdrs)
#     634
#
# ~/opt/anaconda3/lib/python3.9/urllib/request.py in error(self, proto, *args)
#     559         if http_err:
#     560             args = (dict, 'default', 'http_error_default') + orig_args
# --> 561             return self._call_chain(*args)
#     562
#     563 # XXX probably also want an abstract factory that knows when it makes
#
# ~/opt/anaconda3/lib/python3.9/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     492         for handler in handlers:
#     493             func = getattr(handler, meth_name)
# --> 494             result = func(*args)
#     495             if result is not None:
#     496                 return result
#
# ~/opt/anaconda3/lib/python3.9/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     639 class HTTPDefaultErrorHandler(BaseHandler):
#     640     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 641         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     642
#     643 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 403: Forbidden

# %%
import requests


api_data = requests.get('https://api.sampleapis.com/coffee/hot').content

# %%
df = pd.read_json(api_data)

# %%
df.to_csv('coffee.csv')

# %%
df = pd.DataFrame(json.loads(api_data))

# %%
df
# Out:
#               title                                        description  \
# 0      Black Coffee  Svart kaffe är så enkelt som det kan bli med m...
# 1             Latte  Som den mest populära kaffedrycken där ute bes...
# 2     Caramel Latte  Om du gillar latte med en speciell smak kan ka...
# 3        Cappuccino  Cappuccino är en latte som är gjord med mer sk...
# 4         Americano  Med en liknande smak som svart kaffe består am...
# 5          Espresso  Ett espressoskott kan serveras ensamt eller an...
# 6         Macchiato  Macchiaton är en annan espresso-baserad dryck ...
# 7             Mocha  För alla chokladälskare där ute kommer ni att ...
# 8     Hot Chocolate  Under kalla vinterdagar får en kopp varm chokl...
# 9        Chai Latte  Om du letar efter en smakfull varm dryck mitt ...
# 10     Matcha Latte  Matcha latte är en grön, hälsosam kaffedryck m...
# 11    Seasonal Brew  Säsongs kaffe med olika smaktoner som karamell...
# 12         Svart Te  Svart te föddes i Kina. Det är tillverkat av b...
# 13          Islatte  Iced latte är en kyld kaffedryck som görs geno...
# 14    Islatte Mocha  Iced latte Mocha är en kombination av latte oc...
# 15  Frapino Caramel  Det är en blandad eller bättre sagt skakad kaf...
# 16    Frapino Mocka  Ännu en berömd och utsökt kall dryck för dem s...
# 17     Apelsinjuice  Vi har inget att säga om vår nypressade apelsi...
# 18  Frozen Lemonade  Frozen lemonade är en uppfriskande sommardryck...
# 19          Lemonad  Var känd i Paris först och blev sedan mycket p...
#
#                                           ingredients  \
# 0                                            [Coffee]
# 1                             [Espresso, Ångad mjölk]
# 2              [Espresso, Ångad mjölk, Karamellsirap]
# 3                       [Espresso, Ångad mjölk, Foam]
# 4                             [Espresso, Hett vatten]
# 5                                          [Espresso]
# 6                                    [Espresso, Foam]
# 7                    [Espresso, Ångad mjölk, Choklad]
# 8                                    [Choklad, Mjölk]
# 9            [Te, Mjölk, Ingefära, Kardemumma, Kanel]
# 10                    [Matcha-pulver, Mjölk, Socker*]
# 11                                            [Kaffe]
# 12                                               [Te]
# 13                       [Espresso, Mjölk, Is, Sirap]
# 14                    [Espresso, Is, Mjölk, Choklad ]
# 15  [coffee, Is, Mjölk, Karamellsirap, Vispgrädde*...
# 16            [Coffee, Is, Mjölk, Cocoa, Vispgrädde*]
# 17                             [Färska Apelsiner, Is]
# 18                          [Citronsaft, Is, Socker*]
# 19              [Citronsaft, Kolsyrat vatten, Honung]
#
#                                                 image  id
# 0   https://images.unsplash.com/photo-149431467190...   1
# 1   https://images.unsplash.com/photo-1561882468-9...   2
# 2   https://images.unsplash.com/photo-159939805406...   3
# 3   https://images.unsplash.com/photo-1557006021-b...   4
# 4   https://images.unsplash.com/photo-153200449149...   5
# 5   https://images.unsplash.com/photo-157999235715...   6
# 6   https://images.unsplash.com/photo-1557772611-7...   7
# 7   https://images.unsplash.com/photo-160726055077...   8
# 8   https://images.unsplash.com/photo-1542990253-0...   9
# 9   https://images.unsplash.com/photo-157889995210...  10
# 10  https://images.unsplash.com/photo-153625626395...  11
# 11  https://images.unsplash.com/photo-161116245832...  12
# 12  https://images.unsplash.com/photo-157609276824...  13
# 13  https://images.unsplash.com/photo-151770155092...  14
# 14  https://images.unsplash.com/photo-164264739107...  15
# 15  https://images.unsplash.com/photo-166204710260...  16
# 16  https://images.unsplash.com/photo-153037323921...  17
# 17  https://images.unsplash.com/photo-160027188674...  18
# 18  https://images.unsplash.com/photo-152337105410...  19
# 19  https://images.unsplash.com/photo-162126376492...  20

# %%
data = [['s','h','h','d','','5'],['sh','hu','bh','am','gd','5'],['shg','fhu','fbh','sam','dgd','5'],['sh','hu','bh','am','gd','5'],['sh','hu','bh','am','gd','5'],['sh','hu','bh','am','gd','5']]
column_name = ['a','b','c','d','e','f']
df = pd.DataFrame(columns=column_name,index= [1,2,3,4,5,6],data= data)
df
# Out:
#      a    b    c    d    e  f
# 1    s    h    h    d       5
# 2   sh   hu   bh   am   gd  5
# 3  shg  fhu  fbh  sam  dgd  5
# 4   sh   hu   bh   am   gd  5
# 5   sh   hu   bh   am   gd  5
# 6   sh   hu   bh   am   gd  5

# %%
temp = df['c'].copy()
df['c'] = df['e']
df['e'] = temp

# %%
data = {
    'A': [10, 20, 30, 40, 50],
    'B': [60, 70, 80, 90, 100],
    'C': [110, 120, 130, 140, 150]
}
df = pd.DataFrame(data, index=['a', 'b', 'c', 'd', 'e'])

df
# Out:
#     A    B    C
# a  10   60  110
# b  20   70  120
# c  30   80  130
# d  40   90  140
# e  50  100  150

# %%
dict_data = {'page': 2,
 'per_page': 6,
 'total': 12,
 'total_pages': 2,
            }
df = pd.DataFrame([dict_data])       #dict to Dataframe
df
# Out:
#    page  per_page  total  total_pages
# 0     2         6     12            2
