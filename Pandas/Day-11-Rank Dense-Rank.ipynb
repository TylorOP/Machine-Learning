# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/thispc/Desktop/Machine-learning/pandas/kaggle-dataset/Amazon Sale Report.csv')
# Out:
# /Users/thispc/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (23) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df.columns
# Out:
# Index(['index', 'Order ID', 'Date', 'Status', 'Fulfilment', 'Sales Channel ',
#        'ship-service-level', 'Style', 'SKU', 'Category', 'Size', 'ASIN',
#        'Courier Status', 'Qty', 'currency', 'Amount', 'ship-city',
#        'ship-state', 'ship-postal-code', 'ship-country', 'promotion-ids',
#        'B2B', 'fulfilled-by', 'Unnamed: 22'],
#       dtype='object')

# %%
df
# Out:
#          index             Order ID      Date                        Status  \
# 0            0  405-8078784-5731545  04-30-22                     Cancelled
# 1            1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2            2  404-0687676-7273146  04-30-22                       Shipped
# 3            3  403-9615377-8133951  04-30-22                     Cancelled
# 4            4  407-1069790-7240320  04-30-22                       Shipped
# ...        ...                  ...       ...                           ...
# 128970  128970  406-6001380-7673107  05-31-22                       Shipped
# 128971  128971  402-9551604-7544318  05-31-22                       Shipped
# 128972  128972  407-9547469-3152358  05-31-22                       Shipped
# 128973  128973  402-6184140-0545956  05-31-22                       Shipped
# 128974  128974  408-7436540-8728312  05-31-22                       Shipped
#
# ...

# %% [markdown]
# # Question: How would you rank the orders in descending order of the Amount column? What method would you use to ensure that orders with the same Amount have the same rank?

# %%
df.dropna(inplace=True)
df['Amount_rank'] = df['Amount'].rank(method='dense').astype('int')

# %%
df.iloc[:,8:].head(3)
# Out:
#                   SKU       Category Size        ASIN Courier Status  Qty  \
# 49051      J0385-KR-M          kurta    M  B09YYNG98D        Shipped    1
# 49077  JNE3654-TP-XXL            Top  XXL  B09B3GWVJ9        Shipped    1
# 49081   JNE3798-KR-XS  Western Dress   XS  B09SDY7MHD        Shipped    1
#
#       currency  Amount    ship-city      ship-state  ship-postal-code  \
# 49051      INR   888.0  RAJAHMUNDRY  ANDHRA PRADESH          533126.0
# 49077      INR   371.0      CHENNAI      TAMIL NADU          600042.0
# 49081      INR   771.0   NEDUMANGAD          KERALA          695541.0
#
#       ship-country                                      promotion-ids    B2B  \
# 49051           IN  Amazon PLCC Free-Financing Universal Merchant ...  False
# 49077           IN  Amazon PLCC Free-Financing Universal Merchant ...  False
# 49081           IN  Amazon PLCC Free-Financing Universal Merchant ...  False
#
#       fulfilled-by Unnamed: 22  Amount_rank
# ...

# %%
df.query('Amount_rank ==1').head(8).iloc[:,8:]
# Out:
#                   SKU       Category Size        ASIN Courier Status  Qty  \
# 49082      J0152-DR-L  Western Dress    L  B08V197XLZ        Shipped    1
# 49299  SET278-KR-NP-S            Set    S  B0983F2ZJW        Shipped    1
# 49438    JNE3869-DR-L  Western Dress    L  B09RK63SGY        Shipped    1
# 49513   J0117-TP-XXXL            Top  3XL  B08N498WCX        Shipped    1
# 49579     J0189-TP-XL            Top   XL  B08N4TVYBJ        Shipped    1
# 49626      J0339-DR-M  Western Dress    M  B09831YHGV        Shipped    1
# 49780  SET339-KR-NP-S            Set    S  B09RT1WSR9        Shipped    1
# 49795    JNE3905-DR-S  Western Dress    S  B09YYPQ7NW        Shipped    1
#
#       currency  Amount  ship-city       ship-state  ship-postal-code  \
# 49082      INR     0.0        LEH  JAMMU & KASHMIR          194101.0
# 49299      INR     0.0     RAIPUR     CHHATTISGARH          492001.0
# 49438      INR     0.0  BENGALURU        KARNATAKA          560024.0
# ...

# %%
# Question: How would you rank the SKUs within each Category based on the Qty sold?

# %%
df.sort_values('Qty',ascending=False).groupby('Category').cumcount()+1
# Out:
# 113350       1
# 113339       2
# 79899        3
# 120797       4
# 120770       5
#           ...
# 72109     6135
# 72107     6136
# 72101     4438
# 72100     7004
# 128891    4439
# Length: 19379, dtype: int64

# %%
df.columns
# Out:
# Index(['index', 'Order ID', 'Date', 'Status', 'Fulfilment', 'Sales Channel ',
#        'ship-service-level', 'Style', 'SKU', 'Category', 'Size', 'ASIN',
#        'Courier Status', 'Qty', 'currency', 'Amount', 'ship-city',
#        'ship-state', 'ship-postal-code', 'ship-country', 'promotion-ids',
#        'B2B', 'fulfilled-by', 'Unnamed: 22', 'Amount_rank'],
#       dtype='object')

# %%
df.groupby('Category').agg({'Qty':'count'})
# Out:
#                 Qty
# Category
# Blouse           83
# Bottom          123
# Ethnic Dress    156
# Saree            11
# Set            7004
# Top            1427
# Western Dress  4439
# kurta          6136

# %%
df['Rank'] =df.groupby('Category')['Qty'].rank(method = 'dense',ascending= False)

# %%
df.groupby('Category')['Qty'].rank(method = 'dense',ascending= False)
# Out:
# 49051     5.0
# 49077     3.0
# 49081     2.0
# 49082     2.0
# 49083     2.0
#          ...
# 128872    2.0
# 128873    2.0
# 128874    2.0
# 128887    3.0
# 128891    2.0
# Name: Qty, Length: 19379, dtype: float64

# %%
df.groupby('Category')['Qty'].sum()
# Out:
# Category
# Blouse             83
# Bottom            126
# Ethnic Dress      159
# Saree              12
# Set              7027
# Top              1435
# Western Dress    4451
# kurta            6179
# Name: Qty, dtype: int64
