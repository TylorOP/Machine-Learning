# %%
# !pip install matplotlib

# %%
from matplotlib import pyplot as plt
import pandas as pd

# %%
data = {
        'name' : ['shub','ram','rahul','akshay','omkar','don'],
        'age' : [12,4,5,87,3,67],
        'Salary' : [3944,6499,9356,2364,97237,95734]
        
    }

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#      name  age  Salary
# 0    shub   12    3944
# 1     ram    4    6499
# 2   rahul    5    9356
# 3  akshay   87    2364
# 4   omkar    3   97237
# 5     don   67   95734

# %%
plt.plot(df['age'],df['Salary']) # line graph

# %%
plt.scatter(df['age'],df['Salary'])  # scatter chart

# %%
import seaborn as sns

# %%
df = sns.load_dataset('mpg')

# %%
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
plt.scatter(df['mpg'],df['weight'])

# %%
plt.scatter(df['displacement'],df['horsepower'])

# %%
plt.bar(df['acceleration'].unique(),height= df['acceleration'].value_counts())
# Out:
# <BarContainer object of 95 artists>

# %%
df3 = pd.read_csv('/Users/thispc/Desktop/Machine-learning/pandas/kaggle-dataset/Amazon Sale Report.csv')
# Out:
# /Users/thispc/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (23) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df3
# Out:
#          index             Order ID      Date                        Status  \
# 0            0  405-8078784-5731545  04-30-22                     Cancelled
# 1            1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2            2  404-0687676-7273146  04-30-22                       Shipped
# 3            3  403-9615377-8133951  04-30-22                     Cancelled
# 4            4  407-1069790-7240320  04-30-22                       Shipped
# ...        ...                  ...       ...                           ...
# 128970  128970  406-6001380-7673107  05-31-22                       Shipped
# 128971  128971  402-9551604-7544318  05-31-22                       Shipped
# 128972  128972  407-9547469-3152358  05-31-22                       Shipped
# 128973  128973  402-6184140-0545956  05-31-22                       Shipped
# 128974  128974  408-7436540-8728312  05-31-22                       Shipped
#
# ...

# %%
plt.bar(df3['Status'].unique(),height=df3['Status'].value_counts())
# Out:
# <BarContainer object of 13 artists>

# %%
plt.figure(figsize=(70,20))
plt.bar(df3['Status'].unique(),height=df3['Status'].value_counts())
plt.savefig('status-hi.jpg')
plt.show()

# %%
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
df
# Out:
#      name  age  Salary
# 0    shub   12    3944
# 1     ram    4    6499
# 2   rahul    5    9356
# 3  akshay   87    2364
# 4   omkar    3   97237
# 5     don   67   95734

# %%
df.plot(x='name',y=['age','Salary'],kind='bar')
# Out:
# <Axes: xlabel='name'>

# %%
data = {
        'name' : ['shub','ram','rahul','akshay','omkar','don'],
        'age' : [12,4,5,87456543,3,67],
        'Salary' : [3944,6499,9356,2364,97237,95734]
        
    }
df = pd.DataFrame(data)

# %%
df.plot(x='name',y=['age','Salary'],kind='bar') #values in data affect the graph
# Out:
# <Axes: xlabel='name'>

# %%
data = {
        'name' : ['shub','ram','rahul','akshay','omkar','don'],
        'age' : [1652,4545,26065,8543,3,6757],
        'Salary' : [3944,6499,9356,2364,97237,95734]
        
    }
df = pd.DataFrame(data)

# %%
df.plot(x='name',y=['age','Salary'],kind='bar')
# Out:
# <Axes: xlabel='name'>
