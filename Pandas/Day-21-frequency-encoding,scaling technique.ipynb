# %%
import pandas as pd
import seaborn as sns
import numpy as np
from matplotlib import pyplot as plt

# %%
df = sns.load_dataset('titanic')

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
frequencey = df['embarked'].value_counts(normalize=True)

# %%
frequencey
# Out:
# S    0.724409
# C    0.188976
# Q    0.086614
# Name: embarked, dtype: float64

# %%
df['embarked_encoded'] = df['embarked'].map(frequencey)

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
#Scalling

# %%
df = pd.read_csv('/Users/thispc/Desktop/Machine-learning/pandas/kaggle-dataset/auto-mpg.csv')

# %%
#Remove ?

# %%
df.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model year', 'origin', 'car name'],
#       dtype='object')

# %%
df.horsepower.unique()
# Out:
# array(['130', '165', '150', '140', '198', '220', '215', '225', '190',
#        '170', '160', '95', '97', '85', '88', '46', '87', '90', '113',
#        '200', '210', '193', '?', '100', '105', '175', '153', '180', '110',
#        '72', '86', '70', '76', '65', '69', '60', '80', '54', '208', '155',
#        '112', '92', '145', '137', '158', '167', '94', '107', '230', '49',
#        '75', '91', '122', '67', '83', '78', '52', '61', '93', '148',
#        '129', '96', '71', '98', '115', '53', '81', '79', '120', '152',
#        '102', '108', '68', '58', '149', '89', '63', '48', '66', '139',
#        '103', '125', '133', '138', '135', '142', '77', '62', '132', '84',
#        '64', '74', '116', '82'], dtype=object)

# %%
df.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model year      0
# origin          0
# car name        0
# dtype: int64

# %%
df['horsepower'].replace('?','NAN',inplace=True)  #wrong use np.nan

# %%
df.horsepower.unique()
# Out:
# array(['130', '165', '150', '140', '198', '220', '215', '225', '190',
#        '170', '160', '95', '97', '85', '88', '46', '87', '90', '113',
#        '200', '210', '193', 'NAN', '100', '105', '175', '153', '180',
#        '110', '72', '86', '70', '76', '65', '69', '60', '80', '54', '208',
#        '155', '112', '92', '145', '137', '158', '167', '94', '107', '230',
#        '49', '75', '91', '122', '67', '83', '78', '52', '61', '93', '148',
#        '129', '96', '71', '98', '115', '53', '81', '79', '120', '152',
#        '102', '108', '68', '58', '149', '89', '63', '48', '66', '139',
#        '103', '125', '133', '138', '135', '142', '77', '62', '132', '84',
#        '64', '74', '116', '82'], dtype=object)

# %%
df['horsepower'].replace('NAN',np.nan,inplace=True)

# %%
df.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      6
# weight          0
# acceleration    0
# model year      0
# origin          0
# car name        0
# dtype: int64

# %%
df.horsepower.fillna(df.horsepower.mode()[0],inplace=True)

# %%
df.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model year      0
# origin          0
# car name        0
# dtype: int64

# %%
df.drop(['car name'],inplace=True,axis=1)

# %%
X =df.drop('mpg',axis=1)
y = df['mpg']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,train_size=0.70)

# %%
X_train
# Out:
#      cylinders  displacement horsepower  weight  acceleration  model year  \
# 130          4         122.0         80    2451          16.5          74
# 120          4         121.0        112    2868          15.5          73
# 99           6         232.0        100    2945          16.0          73
# 119          4         114.0         91    2582          14.0          73
# 143          4          97.0         78    2300          14.5          74
# ..         ...           ...        ...     ...           ...         ...
# 345          4          81.0         60    1760          16.1          81
# 85           8         350.0        175    4100          13.0          73
# 205          4          97.0         75    2155          16.4          76
# 236          4         140.0         89    2755          15.8          77
# 254          6         200.0         85    2965          15.8          78
#
#      origin
# 130       1
# 120       2
# 99        1
# 119       2
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
obj = StandardScaler()

# %%
X_scale = obj.fit(X_train)

# %%
X_scale
# Out:
# StandardScaler()

# %%
X_train_Scale = obj.transform(X_train)
X_test_Scale = obj.transform(X_test)

# %%
#create dataframe

# %%
X_scale_train_df = pd.DataFrame(X_train_Scale,columns=X_train.columns)

# %%
X_scale_train_df
# Out:
#      cylinders  displacement  horsepower    weight  acceleration  model year  \
# 0    -0.838907     -0.658436   -0.647748 -0.588201      0.358122   -0.535140
# 1    -0.838907     -0.667999    0.188832 -0.083715     -0.012671   -0.802230
# 2     0.347944      0.393520   -0.124885  0.009439      0.172725   -0.802230
# 3    -0.838907     -0.734942   -0.360173 -0.429718     -0.568860   -0.802230
# 4    -0.838907     -0.897517   -0.700034 -0.770880     -0.383464   -0.535140
# ..         ...           ...         ...       ...           ...         ...
# 273  -0.838907     -1.050529   -1.170610 -1.424171      0.209805    1.334489
# 274   1.534794      1.521983    1.835849  1.406755     -0.939653   -0.802230
# 275  -0.838907     -0.897517   -0.778463 -0.946301      0.321043   -0.000961
# 276  -0.838907     -0.486298   -0.412459 -0.220423      0.098567    0.266129
# 277   0.347944      0.087497   -0.517032  0.033635      0.098567    0.533219
#
#        origin
# 0   -0.732537
# ...

# %%
X_scale_test_df = pd.DataFrame(X_test_Scale,columns=X_test.columns)

# %%
X_scale_test_df
# Out:
#      cylinders  displacement  horsepower    weight  acceleration  model year  \
# 0     0.347944      0.077934   -0.203314 -0.197436     -0.012671   -1.603500
# 1     1.534794      1.215959    1.182271  1.015991     -1.125049   -0.802230
# 2     1.534794      2.000145    1.705133  2.093920     -1.495842   -0.268051
# 3     0.347944      0.642165    0.397977  0.571995     -0.160988    0.533219
# 4    -0.838907     -0.887954   -0.961465 -1.079379      1.099707    0.266129
# ..         ...           ...         ...       ...           ...         ...
# 115  -0.838907     -0.667999    0.267262 -0.322046     -0.754256   -0.268051
# 116  -0.838907     -0.954896   -1.353612 -1.381828      0.728915   -0.268051
# 117  -0.838907     -1.012276   -0.909179 -1.145918      0.543518   -0.000961
# 118   1.534794      1.531546    1.234557  1.545882     -1.013811   -0.000961
# 119   1.534794      1.082074    2.306425  2.171347      1.099707   -1.603500
#
#        origin
# 0   -0.732537
# ...

# %% [markdown]
# # As train and test has been encoded so we can send to ml model

# %%
# check any effect occur by scaling

# %%
plt.scatter(X_scale_train_df['displacement'],X_scale_train_df['acceleration'])

# %%
plt.scatter(X_train['displacement'],X_train['acceleration'])

# %% [markdown]
# # No Change  ^

# %%
# Normalization

# %%
# formula

# (X-X_min)/(X_max-X_min)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
obj = MinMaxScaler()

# %%
obj.fit(X_train)
# Out:
# MinMaxScaler()

# %%
X_train_minmax = obj.transform(X_train)
X_test_minmax = obj.transform(X_test)

# %%
X_train_minmax_df = pd.DataFrame(X_train_minmax,columns=X_train.columns)

# %%
X_train_minmax_df
# Out:
#      cylinders  displacement  horsepower    weight  acceleration  model year  \
# 0          0.2      0.139535    0.189944  0.250748      0.490798    0.333333
# 1          0.2      0.136951    0.368715  0.375524      0.429448    0.250000
# 2          0.6      0.423773    0.301676  0.398564      0.460123    0.250000
# 3          0.2      0.118863    0.251397  0.289946      0.337423    0.250000
# 4          0.2      0.074935    0.178771  0.205566      0.368098    0.333333
# ..         ...           ...         ...       ...           ...         ...
# 273        0.2      0.033592    0.078212  0.043986      0.466258    0.916667
# 274        1.0      0.728682    0.720670  0.744165      0.276074    0.250000
# 275        0.2      0.074935    0.162011  0.162178      0.484663    0.500000
# 276        0.2      0.186047    0.240223  0.341712      0.447853    0.583333
# 277        0.6      0.341085    0.217877  0.404548      0.447853    0.666667
#
#      origin
# 0       0.0
# 1       0.5
# ...

# %%
X_test_minmax_df = pd.DataFrame(X_test_minmax,columns=X_test.columns)

# %%
X_test_minmax_df
# Out:
#      cylinders  displacement  horsepower    weight  acceleration  model year  \
# 0          0.6      0.338501    0.284916  0.347397      0.429448    0.000000
# 1          1.0      0.645995    0.581006  0.647516      0.245399    0.250000
# 2          1.0      0.857881    0.692737  0.914123      0.184049    0.416667
# 3          0.6      0.490956    0.413408  0.537702      0.404908    0.666667
# 4          0.2      0.077519    0.122905  0.129264      0.613497    0.583333
# ..         ...           ...         ...       ...           ...         ...
# 115        0.2      0.136951    0.385475  0.316577      0.306748    0.416667
# 116        0.2      0.059432    0.039106  0.054458      0.552147    0.416667
# 117        0.2      0.043928    0.134078  0.112807      0.521472    0.500000
# 118        1.0      0.731266    0.592179  0.778576      0.263804    0.500000
# 119        1.0      0.609819    0.821229  0.933273      0.613497    0.000000
#
#      origin
# 0       0.0
# 1       0.0
# ...

# %% [markdown]
# # Standard rannge is -1 to +1
# # Normalization range is 0 to 1
