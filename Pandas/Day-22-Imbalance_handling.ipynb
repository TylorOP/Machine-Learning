# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/thispc/Desktop/Machine-learning/pandas/kaggle-dataset/creditcard.csv')

# %%
df
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
df.Class.unique()
# Out:
# array([0, 1])

# %%
df.Class.value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
#split

# %%
X = df.drop('Class',axis=1)
y = df['Class']

# %%
pip install imblearn
# Out:
# ...
#   Using cached imblearn-0.0-py2.py3-none-any.whl.metadata (355 bytes)
# ...
# Using cached imblearn-0.0-py2.py3-none-any.whl (1.9 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 258.3/258.3 kB 1.6 MB/s eta 0:00:0000:0100:01m
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
X
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V20       V21  \
# ...

# %%
y
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 284802    0
# 284803    0
# 284804    0
# 284805    0
# 284806    0
# Name: Class, Length: 284807, dtype: int64

# %%
from imblearn.over_sampling import RandomOverSampler

# %%
obj = RandomOverSampler(sampling_strategy=0.40)

# %%
X_Over_sample,y_Over_Sample = obj.fit_resample(X,y)

# %%
X
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V20       V21  \
# ...

# %%
X_Over_sample
# Out:
#             Time         V1         V2         V3        V4         V5  \
# 0            0.0  -1.359807  -0.072781   2.536347  1.378155  -0.338321
# 1            0.0   1.191857   0.266151   0.166480  0.448154   0.060018
# 2            1.0  -1.358354  -1.340163   1.773209  0.379780  -0.503198
# 3            1.0  -0.966272  -0.185226   1.792993 -0.863291  -0.010309
# 4            2.0  -1.158233   0.877737   1.548718  0.403034  -0.407193
# ...          ...        ...        ...        ...       ...        ...
# 398036   86376.0  -0.670238   0.945206   0.610051  2.640065  -2.707775
# 398037   28726.0 -29.876366  16.434525 -30.558697  6.505862 -21.665654
# 398038   93965.0 -11.397727   7.763953 -18.572307  6.711855 -10.174216
# 398039   93853.0  -5.839192   7.151532 -12.816760  7.031115  -9.651272
# 398040  133184.0  -1.212682  -2.484824  -6.397186  3.670562  -0.863375
#
#               V6         V7         V8        V9  ...       V20       V21  \
# ...

# %%
y
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 284802    0
# 284803    0
# 284804    0
# 284805    0
# 284806    0
# Name: Class, Length: 284807, dtype: int64

# %%
y_Over_Sample
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 398036    1
# 398037    1
# 398038    1
# 398039    1
# 398040    1
# Name: Class, Length: 398041, dtype: int64

# %%
# total 398040
y.value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
y_Over_Sample.value_counts()
# Out:
# 0    284315
# 1    113726
# Name: Class, dtype: int64

# %%
# After oversampling 40% increase.  Classifier oversample based of other by 40  
# referencing X it create dummy_value no change and it work on target feature only
(284315/100)*40
# Out:
# 113726.0

# %%
from imblearn.under_sampling import RandomUnderSampler

# %%
obj = RandomUnderSampler(sampling_strategy=0.68)  # so i want other Classifier must be 68% of me (it will reduce itself)

# %%
X_Under_Sample,y_under_Sample = obj.fit_resample(X,y)

# %%
X_Under_Sample
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 170367  120148.0  2.061902 -0.071072 -1.424883  0.141311  0.217487 -0.735424
# 263933  161185.0 -0.490231  0.922322 -0.687238 -0.571772  1.109577 -0.731251
# 166643  118217.0  1.987137 -1.195732 -0.148030 -0.403583 -1.299004  0.023413
# 145908   87272.0 -1.470071  2.796557 -0.128777  4.096901  0.198842  0.802660
# 272869  165304.0 -0.698898  0.812196  1.475654 -0.701722 -0.104815 -0.154156
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
# ...

# %%
y_under_Sample
# Out:
# 170367    0
# 263933    0
# 166643    0
# 145908    0
# 272869    0
#          ..
# 279863    1
# 280143    1
# 280149    1
# 281144    1
# 281674    1
# Name: Class, Length: 1215, dtype: int64

# %%
X
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V20       V21  \
# ...

# %%
y
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 284802    0
# 284803    0
# 284804    0
# 284805    0
# 284806    0
# Name: Class, Length: 284807, dtype: int64

# %%
y.value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
y_under_Sample.value_counts()
# Out:
# 0    723
# 1    492
# Name: Class, dtype: int64

# %%
(723/100)*68
# Out:
# 491.64000000000004

# %%
# from imblearn.under_sampling import NearMiss
# from imblearn.over_sampling import SMOTE
# Are other option as well
# i found an issue with my internal package issue but flow is same

#inshort flow
# import class 
# create obj and give %
# x_sample,y_sample = obj.fit(x,y)
