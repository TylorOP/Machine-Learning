# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/thispc/Desktop/Machine-learning/pandas/kaggle-dataset/Amazon Sale Report.csv')
# Out:
# /Users/thispc/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (23) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df
# Out:
#          index             Order ID      Date                        Status  \
# 0            0  405-8078784-5731545  04-30-22                     Cancelled
# 1            1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2            2  404-0687676-7273146  04-30-22                       Shipped
# 3            3  403-9615377-8133951  04-30-22                     Cancelled
# 4            4  407-1069790-7240320  04-30-22                       Shipped
# ...        ...                  ...       ...                           ...
# 128970  128970  406-6001380-7673107  05-31-22                       Shipped
# 128971  128971  402-9551604-7544318  05-31-22                       Shipped
# 128972  128972  407-9547469-3152358  05-31-22                       Shipped
# 128973  128973  402-6184140-0545956  05-31-22                       Shipped
# 128974  128974  408-7436540-8728312  05-31-22                       Shipped
#
# ...

# %%
df.describe()
# Out:
#                index            Qty         Amount  ship-postal-code
# count  128975.000000  128975.000000  121180.000000     128942.000000
# mean    64487.000000       0.904431     648.561465     463966.236509
# std     37232.019822       0.313354     281.211687     191476.764941
# min         0.000000       0.000000       0.000000     110001.000000
# 25%     32243.500000       1.000000     449.000000     382421.000000
# 50%     64487.000000       1.000000     605.000000     500033.000000
# 75%     96730.500000       1.000000     788.000000     600024.000000
# max    128974.000000      15.000000    5584.000000     989898.000000

# %% [markdown]
# # This is the high level insight
# ## the data clear says bell curved is shifted right side
# ### 1. Null values  amount of count
# ### 2. Outliners     (50 percentile and mean)
# ### 3. Left Skew   (25 - min left tail max- 75 right tail)

# %%
df.describe(include=object)
# Out:
#                    Order ID      Date   Status Fulfilment Sales Channel   \
# count                128975    128975   128975     128975         128975
# unique               120378        91       13          2              2
# top     171-5057375-2831560  05-03-22  Shipped     Amazon      Amazon.in
# freq                     12      2085    77804      89698         128851
#
#        ship-service-level    Style           SKU Category    Size        ASIN  \
# count              128975   128975        128975   128975  128975      128975
# unique                  2     1377          7195        9      11        7190
# top             Expedited  JNE3797  JNE3797-KR-L      Set       M  B09SDXFFQ1
# freq                88615     4224           773    50284   22711         773
#
#        Courier Status currency  ship-city   ship-state ship-country  \
# count          122103   121180     128942       128942       128942
# unique              3        1       8955           69            1
# ...

# %%
df1 = pd.read_csv('prod.csv')

# %%
df1
# Out:
#     prdid      name  price     category
# 0     1.0  Widget A   25.0  Electronics
# 1     2.0  Widget B    NaN  Electronics
# 2     NaN       NaN   25.0  Electronics
# 3     NaN       NaN    NaN          NaN
# 4     3.0  Widget C   30.0     Clothing
# 5     4.0       NaN   20.0       Sports
# 6     5.0  Widget E   25.0     Clothing
# 7     6.0  Widget F   35.0          NaN
# 8     7.0  Widget G    NaN       Sports
# 9     8.0  Widget H   30.0  Electronics
# 10    9.0             40.0     Clothing
# 11   10.0  Widget J   25.0  Electronics
# 12    NaN       NaN    NaN

# %%
df1['name'].value_counts()
# Out:
# Widget J    2
# Widget A    1
# Widget B    1
# Widget C    1
# Widget E    1
# Widget F    1
# Widget G    1
# Widget H    1
# Widget I    1
# Name: name, dtype: int64

# %%
df1['name'].unique()
# Out:
# array(['Widget A', 'Widget B', 'Widget C', nan, 'Widget E', 'Widget F',
#        'Widget G', 'Widget H', 'Widget I', 'Widget J'], dtype=object)

# %%
df1['price'].unique()
# Out:
# array([25., nan, 30., 20., 35., 40.])

# %%
df.columns
# Out:
# Index(['index', 'Order ID', 'Date', 'Status', 'Fulfilment', 'Sales Channel ',
#        'ship-service-level', 'Style', 'SKU', 'Category', 'Size', 'ASIN',
#        'Courier Status', 'Qty', 'currency', 'Amount', 'ship-city',
#        'ship-state', 'ship-postal-code', 'ship-country', 'promotion-ids',
#        'B2B', 'fulfilled-by', 'Unnamed: 22'],
#       dtype='object')

# %%
list(df['ship-city'].unique())
# Out:
# ['MUMBAI',
#  'BENGALURU',
#  'NAVI MUMBAI',
#  'PUDUCHERRY',
#  'CHENNAI',
#  'GHAZIABAD',
#  'CHANDIGARH',
#  'HYDERABAD',
#  'Chennai',
#  'NOIDA',
#  'Amravati.',
#  'GUNTAKAL',
#  'JAIPUR',
#  'NEW DELHI',
#  'Gurgaon',
#  'TIRUCHIRAPPALLI',
#  'pune',
#  'TEZPUR',
#  'RANCHI',
#  'BILASPUR',
#  'PUNE',
#  'GUWAHATI',
#  'THIRUVARUR',
#  'LUCKNOW',
#  'VISAKHAPATNAM',
#  'JEYPUR',
#  'THIRUVANANTHAPURAM',
#  'GREATER NOIDA',
#  'JABALPUR',
#  'KOLKATA',
#  'ONGOLE',
#  'SECUNDERABAD',
#  'KEWALPUR',
#  'CUTTACK',
#  'BADLAPUR',
#  'dimapur',
#  'WARANGAL',
#  'DHAULPUR',
#  'Bengaluru',
#  'NAGPUR',
#  'THANE',
#  'Dahod',
#  'VIJAPURA',
#  'bangalore',
#  'BERHAMPUR',
#  'HIMMATNAGAR',
#  'Kolkata',
#  'DEHRADUN',
#  'DHARMAPURI',
#  'VADODARA',
#  'CHAVAKKAD',
#  'PATNA',
#  'Jammu',
#  'NARNAUND',
#  'Ahmedabad',
#  'AMBARNATH',
#  'GWALIOR',
#  'ROHTAK',
#  'RAMAGUNDAM',
#  'PITHORAGARH',
#  'GUWAHATI, KAMRUP (M)',
#  'KOLAR',
#  'PATIALA',
#  'REWA',
#  'BONGAIGAON',
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128975 entries, 0 to 128974
# Data columns (total 24 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   index               128975 non-null  int64
#  1   Order ID            128975 non-null  object
#  2   Date                128975 non-null  object
#  3   Status              128975 non-null  object
#  4   Fulfilment          128975 non-null  object
#  5   Sales Channel       128975 non-null  object
#  6   ship-service-level  128975 non-null  object
#  7   Style               128975 non-null  object
#  8   SKU                 128975 non-null  object
#  9   Category            128975 non-null  object
#  10  Size                128975 non-null  object
#  11  ASIN                128975 non-null  object
#  12  Courier Status      122103 non-null  object
#  13  Qty                 128975 non-null  int64
#  14  currency            121180 non-null  object
# ...

# %%
df1
# Out:
#     prdid      name  price     category
# 0       1  Widget A   25.0  Electronics
# 1       2  Widget B    NaN  Electronics
# 2       3  Widget C   30.0     Clothing
# 3       4       NaN   20.0       Sports
# 4       5  Widget E   25.0     Clothing
# 5       6  Widget F   35.0          NaN
# 6       7  Widget G    NaN       Sports
# 7       8  Widget H   30.0  Electronics
# 8       9  Widget I   40.0     Clothing
# 9      10  Widget J   25.0  Electronics
# 10     10  Widget J   25.0  Electronics

# %%
df1.drop_duplicates()
# Out:
#    prdid      name  price     category
# 0      1  Widget A   25.0  Electronics
# 1      2  Widget B    NaN  Electronics
# 2      3  Widget C   30.0     Clothing
# 3      4       NaN   20.0       Sports
# 4      5  Widget E   25.0     Clothing
# 5      6  Widget F   35.0          NaN
# 6      7  Widget G    NaN       Sports
# 7      8  Widget H   30.0  Electronics
# 8      9  Widget I   40.0     Clothing
# 9     10  Widget J   25.0  Electronics

# %%
df1.dropna()
# Out:
#     prdid      name  price     category
# 0       1  Widget A   25.0  Electronics
# 2       3  Widget C   30.0     Clothing
# 4       5  Widget E   25.0     Clothing
# 7       8  Widget H   30.0  Electronics
# 8       9  Widget I   40.0     Clothing
# 9      10  Widget J   25.0  Electronics
# 10     10  Widget J   25.0  Electronics

# %%
df1
# Out:
#     prdid      name  price     category
# 0     1.0  Widget A   25.0  Electronics
# 1     2.0  Widget B    NaN  Electronics
# 2     NaN       NaN   25.0  Electronics
# 3     NaN       NaN    NaN          NaN
# 4     3.0  Widget C   30.0     Clothing
# 5     4.0       NaN   20.0       Sports
# 6     NaN  Widget E    NaN     Clothing
# 7     6.0  Widget F   35.0          NaN
# 8     NaN  Widget G    NaN       Sports
# 9     8.0       NaN   30.0  Electronics
# 10    9.0             40.0     Clothing
# 11   10.0       NaN    NaN  Electronics
# 12    NaN       NaN    NaN

# %%
df1.dropna(thresh=3)
# Out:
#     prdid      name  price     category
# 0     1.0  Widget A   25.0  Electronics
# 1     2.0  Widget B    NaN  Electronics
# 4     3.0  Widget C   30.0     Clothing
# 5     4.0       NaN   20.0       Sports
# 7     6.0  Widget F   35.0          NaN
# 9     8.0       NaN   30.0  Electronics
# 10    9.0             40.0     Clothing

# %% [markdown]
# # Atleast 3 value must be present

# %%
df1
# Out:
#     prdid      name  price     category
# 0     1.0  Widget A   25.0  Electronics
# 1     2.0  Widget B    NaN  Electronics
# 2     NaN       NaN   25.0  Electronics
# 3     NaN       NaN    NaN          NaN
# 4     3.0  Widget C   30.0     Clothing
# 5     4.0       NaN   20.0       Sports
# 6     NaN  Widget E    NaN     Clothing
# 7     6.0  Widget F   35.0          NaN
# 8     NaN  Widget G    NaN       Sports
# 9     8.0       NaN   30.0  Electronics
# 10    9.0             40.0     Clothing
# 11   10.0       NaN    NaN  Electronics
# 12    NaN       NaN    NaN

# %%
df1.dropna(how='all')
# Out:
#     prdid      name  price     category
# 0     1.0  Widget A   25.0  Electronics
# 1     2.0  Widget B    NaN  Electronics
# 2     NaN       NaN   25.0  Electronics
# 4     3.0  Widget C   30.0     Clothing
# 5     4.0       NaN   20.0       Sports
# 6     NaN  Widget E    NaN     Clothing
# 7     6.0  Widget F   35.0          NaN
# 8     NaN  Widget G    NaN       Sports
# 9     8.0       NaN   30.0  Electronics
# 10    9.0             40.0     Clothing
# 11   10.0       NaN    NaN  Electronics
# 12    NaN       NaN    NaN

# %% [markdown]
# # how = all means all values must be NAN then it drop

# %%
df1
# Out:
#     prdid      name  price     category
# 0     1.0  Widget A   25.0  Electronics
# 1     2.0  Widget B    NaN  Electronics
# 2     NaN       NaN   25.0  Electronics
# 3     NaN       NaN    NaN          NaN
# 4     3.0  Widget C   30.0     Clothing
# 5     4.0       NaN   20.0       Sports
# 6     NaN  Widget E    NaN     Clothing
# 7     6.0  Widget F   35.0          NaN
# 8     NaN  Widget G    NaN       Sports
# 9     8.0       NaN   30.0  Electronics
# 10    9.0             40.0     Clothing
# 11   10.0       NaN    NaN  Electronics
# 12    NaN       NaN    NaN

# %%
df1.fillna(0)
# Out:
#     prdid      name  price     category
# 0     1.0  Widget A   25.0  Electronics
# 1     2.0  Widget B    0.0  Electronics
# 2     0.0         0   25.0  Electronics
# 3     0.0         0    0.0            0
# 4     3.0  Widget C   30.0     Clothing
# 5     4.0         0   20.0       Sports
# 6     0.0  Widget E    0.0     Clothing
# 7     6.0  Widget F   35.0            0
# 8     0.0  Widget G    0.0       Sports
# 9     8.0         0   30.0  Electronics
# 10    9.0             40.0     Clothing
# 11   10.0         0    0.0  Electronics
# 12    0.0         0    0.0

# %%
df1.fillna('shub_the_boss')
# Out:
#             prdid           name          price       category
# 0             1.0       Widget A           25.0    Electronics
# 1             2.0       Widget B  shub_the_boss    Electronics
# 2   shub_the_boss  shub_the_boss           25.0    Electronics
# 3   shub_the_boss  shub_the_boss  shub_the_boss  shub_the_boss
# 4             3.0       Widget C           30.0       Clothing
# 5             4.0  shub_the_boss           20.0         Sports
# 6   shub_the_boss       Widget E  shub_the_boss       Clothing
# 7             6.0       Widget F           35.0  shub_the_boss
# 8   shub_the_boss       Widget G  shub_the_boss         Sports
# 9             8.0  shub_the_boss           30.0    Electronics
# 10            9.0                          40.0       Clothing
# 11           10.0  shub_the_boss  shub_the_boss    Electronics
# 12  shub_the_boss  shub_the_boss  shub_the_boss

# %%
df1
# Out:
#     prdid      name  price     category
# 0     1.0  Widget A   25.0  Electronics
# 1     2.0  Widget B    NaN  Electronics
# 2     NaN       NaN   25.0  Electronics
# 3     NaN       NaN    NaN          NaN
# 4     3.0  Widget C   30.0     Clothing
# 5     4.0       NaN   20.0       Sports
# 6     NaN  Widget E    NaN     Clothing
# 7     6.0  Widget F   35.0          NaN
# 8     NaN  Widget G    NaN       Sports
# 9     8.0       NaN   30.0  Electronics
# 10    9.0             40.0     Clothing
# 11   10.0       NaN    NaN  Electronics
# 12    NaN       NaN    NaN

# %%
df1.fillna(method='ffill')
# Out:
#     prdid      name  price     category
# 0     1.0  Widget A   25.0  Electronics
# 1     2.0  Widget B   25.0  Electronics
# 2     2.0  Widget B   25.0  Electronics
# 3     2.0  Widget B   25.0  Electronics
# 4     3.0  Widget C   30.0     Clothing
# 5     4.0  Widget C   20.0       Sports
# 6     4.0  Widget E   20.0     Clothing
# 7     6.0  Widget F   35.0     Clothing
# 8     6.0  Widget G   35.0       Sports
# 9     8.0  Widget G   30.0  Electronics
# 10    9.0             40.0     Clothing
# 11   10.0             40.0  Electronics
# 12   10.0             40.0

# %%
df1.fillna(method='bfill')
# Out:
#     prdid      name  price     category
# 0     1.0  Widget A   25.0  Electronics
# 1     2.0  Widget B   25.0  Electronics
# 2     3.0  Widget C   25.0  Electronics
# 3     3.0  Widget C   30.0     Clothing
# 4     3.0  Widget C   30.0     Clothing
# 5     4.0  Widget E   20.0       Sports
# 6     6.0  Widget E   35.0     Clothing
# 7     6.0  Widget F   35.0       Sports
# 8     8.0  Widget G   30.0       Sports
# 9     8.0             30.0  Electronics
# 10    9.0             40.0     Clothing
# 11   10.0       NaN    NaN  Electronics
# 12    NaN       NaN    NaN

# %%
df1
# Out:
#     prdid      name  price     category
# 0     1.0  Widget A   25.0  Electronics
# 1     2.0  Widget B    NaN  Electronics
# 2     NaN       NaN   25.0  Electronics
# 3     NaN       NaN    NaN          NaN
# 4     3.0  Widget C   30.0     Clothing
# 5     4.0       NaN   20.0       Sports
# 6     NaN  Widget E    NaN     Clothing
# 7     6.0  Widget F   35.0          NaN
# 8     NaN  Widget G    NaN       Sports
# 9     8.0       NaN   30.0  Electronics
# 10    9.0             40.0     Clothing
# 11   10.0       NaN    NaN  Electronics
# 12    NaN       NaN    NaN

# %%
df1.fillna(method='bfill',limit=1)
# Out:
#     prdid      name  price     category
# 0     1.0  Widget A   25.0  Electronics
# 1     2.0  Widget B   25.0  Electronics
# 2     NaN       NaN   25.0  Electronics
# 3     3.0  Widget C   30.0     Clothing
# 4     3.0  Widget C   30.0     Clothing
# 5     4.0  Widget E   20.0       Sports
# 6     6.0  Widget E   35.0     Clothing
# 7     6.0  Widget F   35.0       Sports
# 8     8.0  Widget G   30.0       Sports
# 9     8.0             30.0  Electronics
# 10    9.0             40.0     Clothing
# 11   10.0       NaN    NaN  Electronics
# 12    NaN       NaN    NaN
