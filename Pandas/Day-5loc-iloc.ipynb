# %%
import pandas as pd

# %%
df = pd.read_csv('https://docs.google.com/spreadsheets/d/1gcvsEgaG0EvWeL-bcasrkbMB9EAe2z6WVv7j9QE2acA/export?format=csv')

# %%
# Out:
#   hsd1` wedsafds` wgrfd qerfd
# 0  afsg        ds   NaN   NaN
# 1   NaN       NaN   dvf   NaN
# 2   NaN       NaN   NaN   daf

# %%
df =pd.read_csv('/Users/thispc/Desktop/Machine-learning/pandas/prod.csv')

# %%
df
# Out:
#     prdid      name  price     category
# 0       1  Widget A   25.0  Electronics
# 1       2  Widget B    NaN  Electronics
# 2       3  Widget C   30.0     Clothing
# 3       4       NaN   20.0       Sports
# 4       5  Widget E   25.0     Clothing
# 5       6  Widget F   35.0          NaN
# 6       7  Widget G    NaN       Sports
# 7       8  Widget H   30.0  Electronics
# 8       9  Widget I   40.0     Clothing
# 9      10  Widget J   25.0  Electronics
# 10     10  Widget J   25.0  Electronics

# %%
df = df.drop_duplicates()

# %%
df
# Out:
#    prdid      name  price     category
# 0      1  Widget A   25.0  Electronics
# 1      2  Widget B    NaN  Electronics
# 2      3  Widget C   30.0     Clothing
# 3      4       NaN   20.0       Sports
# 4      5  Widget E   25.0     Clothing
# 5      6  Widget F   35.0          NaN
# 6      7  Widget G    NaN       Sports
# 7      8  Widget H   30.0  Electronics
# 8      9  Widget I   40.0     Clothing
# 9     10  Widget J   25.0  Electronics

# %%
df.fillna({'name':'shub','price':5})
# Out:
#    prdid      name  price     category
# 0      1  Widget A   25.0  Electronics
# 1      2  Widget B    5.0  Electronics
# 2      3  Widget C   30.0     Clothing
# 3      4      shub   20.0       Sports
# 4      5  Widget E   25.0     Clothing
# 5      6  Widget F   35.0          NaN
# 6      7  Widget G    5.0       Sports
# 7      8  Widget H   30.0  Electronics
# 8      9  Widget I   40.0     Clothing
# 9     10  Widget J   25.0  Electronics

# %%
df.loc[0:3,['prdid','name']]
# Out:
#    prdid      name
# 0      1  Widget A
# 1      2  Widget B
# 2      3  Widget C
# 3      4       NaN

# %%
df
# Out:
#    prdid      name  price     category
# 0      1  Widget A   25.0  Electronics
# 1      2  Widget B    NaN  Electronics
# 2      3  Widget C   30.0     Clothing
# 3      4       NaN   20.0       Sports
# 4      5  Widget E   25.0     Clothing
# 5      6  Widget F   35.0          NaN
# 6      7  Widget G    NaN       Sports
# 7      8  Widget H   30.0  Electronics
# 8      9  Widget I   40.0     Clothing
# 9     10  Widget J   25.0  Electronics

# %%
#Select the name and price of the product with prdid 4 using loc

df.loc[3:3,['name','price']]
# Out:
#   name  price
# 3  NaN   20.0

# %%
df
# Out:
#    prdid      name  price     category
# 0      1  Widget A   25.0  Electronics
# 1      2  Widget B    NaN  Electronics
# 2      3  Widget C   30.0     Clothing
# 3      4       NaN   20.0       Sports
# 4      5  Widget E   25.0     Clothing
# 5      6  Widget F   35.0          NaN
# 6      7  Widget G    NaN       Sports
# 7      8  Widget H   30.0  Electronics
# 8      9  Widget I   40.0     Clothing
# 9     10  Widget J   25.0  Electronics

# %%
#Get all rows where the category is 'Electronics' using iloc.

# %%
df[df['category'] == 'Electronics'].iloc[:]
# Out:
#    prdid      name  price     category
# 0      1  Widget A   25.0  Electronics
# 1      2  Widget B    NaN  Electronics
# 7      8  Widget H   30.0  Electronics
# 9     10  Widget J   25.0  Electronics

# %%
df
# Out:
#    prdid      name  price     category
# 0      1  Widget A   25.0  Electronics
# 1      2  Widget B    NaN  Electronics
# 2      3  Widget C   30.0     Clothing
# 3      4       NaN   20.0       Sports
# 4      5  Widget E   25.0     Clothing
# 5      6  Widget F   35.0          NaN
# 6      7  Widget G    NaN       Sports
# 7      8  Widget H   30.0  Electronics
# 8      9  Widget I   40.0     Clothing
# 9     10  Widget J   25.0  Electronics

# %%
#Select the price of the product with prdid 5 using iloc.

# %%
df.iloc[[4],[2]]
# Out:
#    price
# 4   25.0

# %%
df
# Out:
#    prdid      name  price     category
# 0      1  Widget A   25.0  Electronics
# 1      2  Widget B    NaN  Electronics
# 2      3  Widget C   30.0     Clothing
# 3      4       NaN   20.0       Sports
# 4      5  Widget E   25.0     Clothing
# 5      6  Widget F   35.0          NaN
# 6      7  Widget G    NaN       Sports
# 7      8  Widget H   30.0  Electronics
# 8      9  Widget I   40.0     Clothing
# 9     10  Widget J   25.0  Electronics

# %%
#Get the names of the first 3 products using loc.

# %%
df.loc[0:2,['name']]
# Out:
#        name
# 0  Widget A
# 1  Widget B
# 2  Widget C

# %%
df
# Out:
#    prdid      name  price     category
# 0      1  Widget A   25.0  Electronics
# 1      2  Widget B    NaN  Electronics
# 2      3  Widget C   30.0     Clothing
# 3      4       NaN   20.0       Sports
# 4      5  Widget E   25.0     Clothing
# 5      6  Widget F   35.0          NaN
# 6      7  Widget G    NaN       Sports
# 7      8  Widget H   30.0  Electronics
# 8      9  Widget I   40.0     Clothing
# 9     10  Widget J   25.0  Electronics

# %%
df.iloc[4:9,1:4]
# Out:
#        name  price     category
# 4  Widget E   25.0     Clothing
# 5  Widget F   35.0          NaN
# 6  Widget G    NaN       Sports
# 7  Widget H   30.0  Electronics
# 8  Widget I   40.0     Clothing

# %%
df
# Out:
#    prdid      name  price     category
# 0      1  Widget A   25.0  Electronics
# 1      2  Widget B    NaN  Electronics
# 2      3  Widget C   30.0     Clothing
# 3      4       NaN   20.0       Sports
# 4      5  Widget E   25.0     Clothing
# 5      6  Widget F   35.0          NaN
# 6      7  Widget G    NaN       Sports
# 7      8  Widget H   30.0  Electronics
# 8      9  Widget I   40.0     Clothing
# 9     10  Widget J   25.0  Electronics

# %%
df.loc[3:6,'name':]
# Out:
#        name  price  category
# 3       NaN   20.0    Sports
# 4  Widget E   25.0  Clothing
# 5  Widget F   35.0       NaN
# 6  Widget G    NaN    Sports

# %%
df
# Out:
#    prdid      name  price     category
# 0      1  Widget A   25.0  Electronics
# 1      2  Widget B    NaN  Electronics
# 2      3  Widget C   30.0     Clothing
# 3      4       NaN   20.0       Sports
# 4      5  Widget E   25.0     Clothing
# 5      6  Widget F   35.0          NaN
# 6      7  Widget G    NaN       Sports
# 7      8  Widget H   30.0  Electronics
# 8      9  Widget I   40.0     Clothing
# 9     10  Widget J   25.0  Electronics

# %%
#id 4 to 8 and corresponding catogory using both

# %%
df.loc[4:8,['prdid','category']]
# Out:
#    prdid     category
# 4      5     Clothing
# 5      6          NaN
# 6      7       Sports
# 7      8  Electronics
# 8      9     Clothing

# %%
df.loc[[4,5,8],['prdid','category']]
# Out:
#    prdid  category
# 4      5  Clothing
# 5      6       NaN
# 8      9  Clothing

# %%
df.iloc[4:9,[1,-1]]
# Out:
#        name     category
# 4  Widget E     Clothing
# 5  Widget F          NaN
# 6  Widget G       Sports
# 7  Widget H  Electronics
# 8  Widget I     Clothing

# %%
df.iloc[[4,5,9],[1,-1]]
# Out:
#        name     category
# 4  Widget E     Clothing
# 5  Widget F          NaN
# 9  Widget J  Electronics

# %%
df
# Out:
#    prdid      name  price     category
# 0      1  Widget A   25.0  Electronics
# 1      2  Widget B    NaN  Electronics
# 2      3  Widget C   30.0     Clothing
# 3      4       NaN   20.0       Sports
# 4      5  Widget E   25.0     Clothing
# 5      6  Widget F   35.0          NaN
# 6      7  Widget G    NaN       Sports
# 7      8  Widget H   30.0  Electronics
# 8      9  Widget I   40.0     Clothing
# 9     10  Widget J   25.0  Electronics

# %%
df.iloc[[4,5,9],1:3]
# Out:
#        name  price
# 4  Widget E   25.0
# 5  Widget F   35.0
# 9  Widget J   25.0

# %%
df.iloc[[4,5,9],[1,2,3]]
# Out:
#        name  price     category
# 4  Widget E   25.0     Clothing
# 5  Widget F   35.0          NaN
# 9  Widget J   25.0  Electronics

# %%
#error example

# %%
df.loc[[4,5,9],[1,2,3]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/28/xzg4vjpj3gj6x32fqvxyzd440000gn/T/ipykernel_4912/1122457603.py in <module>
# ----> 1 df.loc[[4,5,9],[1,2,3]]
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     923                 with suppress(KeyError, IndexError):
#     924                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 925             return self._getitem_tuple(key)
#     926         else:
#     927             # we by definition only have the 0th axis
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1105         # ugly hack for GH #836
#    1106         if self._multi_take_opportunity(tup):
# -> 1107             return self._multi_take(tup)
#    1108
#    1109         return self._getitem_tuple_same_dim(tup)
#
# ...

# %%
df.iloc[[4,5,8],['prdid','category']]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/28/xzg4vjpj3gj6x32fqvxyzd440000gn/T/ipykernel_4912/656757035.py in <module>
# ----> 1 df.iloc[[4,5,8],['prdid','category']]
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     923                 with suppress(KeyError, IndexError):
#     924                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 925             return self._getitem_tuple(key)
#     926         else:
#     927             # we by definition only have the 0th axis
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1504     def _getitem_tuple(self, tup: tuple):
#    1505
# -> 1506         self._has_valid_tuple(tup)
#    1507         with suppress(IndexingError):
#    1508             return self._getitem_lowerdim(tup)
# ...
