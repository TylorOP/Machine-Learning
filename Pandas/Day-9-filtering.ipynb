# %%
from datetime import datetime
import pandas as pd

# %%
df = pd.read_csv('/Users/thispc/Desktop/Machine-learning/pandas/kaggle-dataset/Amazon Sale Report.csv')
# Out:
# /Users/thispc/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (23) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df.dtypes
# Out:
# index                   int64
# Order ID               object
# Date                   object
# Status                 object
# Fulfilment             object
# Sales Channel          object
# ship-service-level     object
# Style                  object
# SKU                    object
# Category               object
# Size                   object
# ASIN                   object
# Courier Status         object
# Qty                     int64
# currency               object
# Amount                float64
# ship-city              object
# ship-state             object
# ship-postal-code      float64
# ship-country           object
# promotion-ids          object
# B2B                      bool
# fulfilled-by           object
# Unnamed: 22            object
# dtype: object

# %%
df.columns
# Out:
# Index(['index', 'Order ID', 'Date', 'Status', 'Fulfilment', 'Sales Channel ',
#        'ship-service-level', 'Style', 'SKU', 'Category', 'Size', 'ASIN',
#        'Courier Status', 'Qty', 'currency', 'Amount', 'ship-city',
#        'ship-state', 'ship-postal-code', 'ship-country', 'promotion-ids',
#        'B2B', 'fulfilled-by', 'Unnamed: 22'],
#       dtype='object')

# %% [markdown]
# # logical Base filtering

# %%
# &
df[(df['Status'] == 'Shipped - Delivered to Buyer') & (df['Qty'] > 4)]
# Out:
#          index             Order ID      Date                        Status  \
# 11160    11160  403-4106553-1691525  04-23-22  Shipped - Delivered to Buyer
# 113350  113350  403-4040971-3884354  06-11-22  Shipped - Delivered to Buyer
#
#        Fulfilment Sales Channel  ship-service-level    Style             SKU  \
# 11160    Merchant      Amazon.in           Standard    J0013  J0013-SKD-XXXL
# 113350   Merchant      Amazon.in           Standard  JNE3405   JNE3405-KR-XL
#
#        Category  ... currency  Amount  ship-city     ship-state  \
# 11160       Set  ...      INR  5495.0  JALANDHAR         PUNJAB
# 113350    kurta  ...      INR  2175.0    ALIGARH  UTTAR PRADESH
#
#        ship-postal-code  ship-country  \
# 11160          144022.0            IN
# 113350         202001.0            IN
#
#                                             promotion-ids    B2B  \
# 11160   Amazon PLCC Free-Financing Universal Merchant ...   True
# ...

# %% [markdown]
# # Filter the DataFrame to show orders that were either fulfilled-by 'Amazon' or currency is 'EUR', and the Amount is less than 500.

# %%
#my ans wrong parnetheses. (() or ()) and ()
df[(df['Fulfilment'] == 'Amazon') | (df['currency'] == 'EUR') & (df['Amount'] >500)]


#google
df[((df['Fulfilment'] == 'Amazon') | (df['currency'] == 'EUR')) & (df['Amount'] < 500)]
# Out:
#          index             Order ID      Date     Status Fulfilment  \
# 2            2  404-0687676-7273146  04-30-22    Shipped     Amazon
# 9            9  402-4393761-0311520  04-30-22    Shipped     Amazon
# 11          11  171-4638481-6326716  04-30-22    Shipped     Amazon
# 16          16  406-9379318-6555504  04-30-22    Shipped     Amazon
# 17          17  405-9013803-8009918  04-30-22    Shipped     Amazon
# ...        ...                  ...       ...        ...        ...
# 128944  128944  404-3730733-2137156  05-31-22    Shipped     Amazon
# 128945  128945  408-8718755-6521128  05-31-22  Cancelled     Amazon
# 128952  128952  404-8878574-4524358  05-31-22    Shipped     Amazon
# 128953  128953  404-8878574-4524358  05-31-22    Shipped     Amazon
# 128959  128959  403-9813694-4657102  05-31-22    Shipped     Amazon
#
#        Sales Channel  ship-service-level    Style             SKU Category  \
# ...

# %% [markdown]
# # How can you filter out all rows where Category is 'Electronics' and Qty is equal to 1?

# %%
df[(df['Category'] == 'Ethnic Dress') & (df['Qty'] == 1)].iloc[:,:16]
# Out:
#          index             Order ID      Date                        Status  \
# 40          40  408-7165704-5643524  04-30-22                       Shipped
# 163        163  407-6283946-7749133  04-30-22                       Shipped
# 402        402  171-2644368-7969167  04-30-22                       Shipped
# 513        513  408-0666162-2209142  04-30-22                       Shipped
# 980        980  403-8342497-0727510  04-30-22  Shipped - Delivered to Buyer
# ...        ...                  ...       ...                           ...
# 128721  128721  407-0181187-1589120  06-01-22                       Shipped
# 128728  128728  403-5231837-4026702  06-01-22                       Shipped
# 128821  128821  405-2783279-2428340  06-01-22                       Shipped
# 128872  128872  405-4724097-1016369  06-01-22  Shipped - Delivered to Buyer
# 128921  128921  406-1847010-7229944  05-31-22                       Shipped
#
# ...

# %%
df['Category'].unique()
# Out:
# array(['Set', 'kurta', 'Western Dress', 'Top', 'Ethnic Dress', 'Bottom',
#        'Saree', 'Blouse', 'Dupatta'], dtype=object)

# %% [markdown]
# # How would you filter the DataFrame to display only rows where the ship-state contains the word 'California'?

# %%
df.dropna(inplace=True)

# %%
df[df['ship-state'].str.contains('New Delhi')]
# Out:
#          index             Order ID      Date                        Status  \
# 51251    51251  406-9472584-9876358  05-30-22  Shipped - Delivered to Buyer
# 69894    69894  408-5751768-0277126  05-15-22  Shipped - Delivered to Buyer
# 70499    70499  404-2921989-6729919  05-14-22  Shipped - Delivered to Buyer
# 78287    78287  403-5997413-8502718  05-08-22  Shipped - Delivered to Buyer
# 83199    83199  171-7922005-4813161  05-04-22  Shipped - Delivered to Buyer
# 86137    86137  403-8808226-0287518  05-03-22  Shipped - Delivered to Buyer
# 86561    86561  408-1641403-7417920  05-03-22  Shipped - Delivered to Buyer
# 102159  102159  402-1114501-5836355  06-20-22  Shipped - Delivered to Buyer
# 113509  113509  171-9619081-1061969  06-11-22  Shipped - Delivered to Buyer
# 126167  126167  402-4664529-4900312  06-02-22  Shipped - Delivered to Buyer
#
#        Fulfilment Sales Channel  ship-service-level    Style              SKU  \
# ...

# %% [markdown]
# # Filter the DataFrame to show only rows where the SKU starts with 'ABC' and ends with 'XYZ'.

# %%
df['SKU'].unique()
# Out:
# array(['J0385-KR-M', 'JNE3654-TP-XXL', 'JNE3798-KR-XS', ...,
#        'J0157-DR-XS', 'JNE3560-KR-S', 'J0079-SKD-S'], dtype=object)

# %%
#startswith J0 - endswith XS

# %%
df[(df['SKU'].str.startswith('J0')) & (df['SKU'].str.endswith('XS'))]
# Out:
#          index             Order ID      Date                        Status  \
# 49171    49171  171-4336198-0844362  05-31-22  Shipped - Delivered to Buyer
# 50071    50071  406-7055418-2742724  05-31-22  Shipped - Delivered to Buyer
# 50793    50793  405-2322241-9297125  05-30-22  Shipped - Delivered to Buyer
# 51220    51220  406-0746196-6800307  05-30-22  Shipped - Delivered to Buyer
# 51552    51552  404-9932919-6662730  05-30-22  Shipped - Delivered to Buyer
# ...        ...                  ...       ...                           ...
# 128525  128525  402-1802800-7501130  06-01-22  Shipped - Returned to Seller
# 128544  128544  405-4945057-9376333  06-01-22  Shipped - Delivered to Buyer
# 128619  128619  407-3696081-5278715  06-01-22  Shipped - Delivered to Buyer
# 128684  128684  403-5744657-5289101  06-01-22  Shipped - Delivered to Buyer
# 128844  128844  407-0622210-6994741  06-01-22  Shipped - Delivered to Buyer
#
# ...

# %% [markdown]
# # How can you filter the DataFrame to display rows where the Style contains the substring 'classic', ignoring case sensitivity?

# %%
df[df['Style'].str.contains('JNE3654',case=False)]
# Out:
#          index             Order ID      Date                        Status  \
# 49077    49077  402-7697834-2682766  05-31-22  Shipped - Delivered to Buyer
# 55313    55313  407-0095089-7337106  05-27-22  Shipped - Delivered to Buyer
# 60083    60083  407-7970353-1563564  05-23-22  Shipped - Returned to Seller
# 65809    65809  408-2273880-2277157  05-18-22  Shipped - Delivered to Buyer
# 66506    66506  402-7237211-6309963  05-17-22  Shipped - Delivered to Buyer
# 68215    68215  408-6839635-3848367  05-16-22  Shipped - Delivered to Buyer
# 69979    69979  408-0485888-8576356  05-15-22  Shipped - Delivered to Buyer
# 70382    70382  408-6479380-5839512  05-14-22  Shipped - Delivered to Buyer
# 71201    71201  403-6571482-0437908  05-14-22  Shipped - Returned to Seller
# 73300    73300  171-7912129-7614701  05-12-22  Shipped - Delivered to Buyer
# 73301    73301  171-7912129-7614701  05-12-22  Shipped - Delivered to Buyer
# ...

# %% [markdown]
# # Write a query to filter rows where the B2B column is True and the ship-country is 'Canada'.

# %%
df.query('(Amount > 300 )')
# Out:
#          index             Order ID      Date                        Status  \
# 49051    49051  408-4858463-2356347  05-31-22  Shipped - Delivered to Buyer
# 49077    49077  402-7697834-2682766  05-31-22  Shipped - Delivered to Buyer
# 49081    49081  402-7031777-0396341  05-31-22  Shipped - Delivered to Buyer
# 49083    49083  403-3845187-4421165  05-31-22  Shipped - Delivered to Buyer
# 49086    49086  171-1835528-9515557  05-31-22  Shipped - Delivered to Buyer
# ...        ...                  ...       ...                           ...
# 128872  128872  405-4724097-1016369  06-01-22  Shipped - Delivered to Buyer
# 128873  128873  405-4724097-1016369  06-01-22  Shipped - Delivered to Buyer
# 128874  128874  405-4724097-1016369  06-01-22  Shipped - Delivered to Buyer
# 128887  128887  405-6493630-8542756  05-31-22  Shipped - Delivered to Buyer
# 128891  128891  403-0317423-9322704  05-31-22  Shipped - Delivered to Buyer
#
# ...

# %%
df.query("500 < Amount < 2000 ")
# Out:
#          index             Order ID      Date                        Status  \
# 49051    49051  408-4858463-2356347  05-31-22  Shipped - Delivered to Buyer
# 49081    49081  402-7031777-0396341  05-31-22  Shipped - Delivered to Buyer
# 49083    49083  403-3845187-4421165  05-31-22  Shipped - Delivered to Buyer
# 49086    49086  171-1835528-9515557  05-31-22  Shipped - Delivered to Buyer
# 49090    49090  407-3443436-4510708  05-31-22  Shipped - Delivered to Buyer
# ...        ...                  ...       ...                           ...
# 128872  128872  405-4724097-1016369  06-01-22  Shipped - Delivered to Buyer
# 128873  128873  405-4724097-1016369  06-01-22  Shipped - Delivered to Buyer
# 128874  128874  405-4724097-1016369  06-01-22  Shipped - Delivered to Buyer
# 128887  128887  405-6493630-8542756  05-31-22  Shipped - Delivered to Buyer
# 128891  128891  403-0317423-9322704  05-31-22  Shipped - Delivered to Buyer
#
# ...

# %%
df.query('100 < Amount < 1000 & currency == "INR"')
# Out:
#          index             Order ID      Date                        Status  \
# 49051    49051  408-4858463-2356347  05-31-22  Shipped - Delivered to Buyer
# 49077    49077  402-7697834-2682766  05-31-22  Shipped - Delivered to Buyer
# 49081    49081  402-7031777-0396341  05-31-22  Shipped - Delivered to Buyer
# 49083    49083  403-3845187-4421165  05-31-22  Shipped - Delivered to Buyer
# 49086    49086  171-1835528-9515557  05-31-22  Shipped - Delivered to Buyer
# ...        ...                  ...       ...                           ...
# 128869  128869  406-3695146-6880344  06-01-22  Shipped - Delivered to Buyer
# 128872  128872  405-4724097-1016369  06-01-22  Shipped - Delivered to Buyer
# 128874  128874  405-4724097-1016369  06-01-22  Shipped - Delivered to Buyer
# 128887  128887  405-6493630-8542756  05-31-22  Shipped - Delivered to Buyer
# 128891  128891  403-0317423-9322704  05-31-22  Shipped - Delivered to Buyer
#
# ...

# %%
df.query('Qty > 2 & (Status == "Shipped - Returned to Seller" | Status == "Shipped - Out for Delivery") & "Sales Channel" != "Online"')
# Out:
#          index             Order ID      Date                        Status  \
# 79891    79891  405-7311519-3898766  05-07-22  Shipped - Returned to Seller
# 79899    79899  405-6877720-7865168  05-07-22  Shipped - Returned to Seller
# 79902    79902  405-4225331-3338755  05-07-22  Shipped - Returned to Seller
# 79903    79903  405-4225331-3338755  05-07-22  Shipped - Returned to Seller
# 120770  120770  402-7744718-3391556  06-06-22  Shipped - Returned to Seller
# 120797  120797  404-3709653-3513958  06-06-22  Shipped - Returned to Seller
#
#        Fulfilment Sales Channel  ship-service-level    Style  \
# 79891    Merchant      Amazon.in           Standard  JNE2171
# 79899    Merchant      Amazon.in           Standard  JNE2086
# 79902    Merchant      Amazon.in           Standard  JNE3671
# 79903    Merchant      Amazon.in           Standard  JNE3673
# 120770   Merchant      Amazon.in           Standard  JNE3609
# 120797   Merchant      Amazon.in           Standard  JNE3739
#
# ...
