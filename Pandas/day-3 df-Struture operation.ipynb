# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/thispc/Desktop/Machine-learning/pandas/kaggle-dataset/Amazon Sale Report.csv')
# Out:
# /Users/thispc/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (23) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df
# Out:
#          index             Order ID      Date                        Status  \
# 0            0  405-8078784-5731545  04-30-22                     Cancelled
# 1            1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2            2  404-0687676-7273146  04-30-22                       Shipped
# 3            3  403-9615377-8133951  04-30-22                     Cancelled
# 4            4  407-1069790-7240320  04-30-22                       Shipped
# ...        ...                  ...       ...                           ...
# 128970  128970  406-6001380-7673107  05-31-22                       Shipped
# 128971  128971  402-9551604-7544318  05-31-22                       Shipped
# 128972  128972  407-9547469-3152358  05-31-22                       Shipped
# 128973  128973  402-6184140-0545956  05-31-22                       Shipped
# 128974  128974  408-7436540-8728312  05-31-22                       Shipped
#
# ...

# %%
row,col = df.shape

# %% [markdown]
# # The Number of Row are 128975 and column are 24

# %%
df.columns
# Out:
# Index(['index', 'Order ID', 'Date', 'Status', 'Fulfilment', 'Sales Channel ',
#        'ship-service-level', 'Style', 'SKU', 'Category', 'Size', 'ASIN',
#        'Courier Status', 'Qty', 'currency', 'Amount', 'ship-city',
#        'ship-state', 'ship-postal-code', 'ship-country', 'promotion-ids',
#        'B2B', 'fulfilled-by', 'Unnamed: 22'],
#       dtype='object')

# %%
df[['Status']]
# Out:
#                               Status
# 0                          Cancelled
# 1       Shipped - Delivered to Buyer
# 2                            Shipped
# 3                          Cancelled
# 4                            Shipped
# ...                              ...
# 128970                       Shipped
# 128971                       Shipped
# 128972                       Shipped
# 128973                       Shipped
# 128974                       Shipped
#
# [128975 rows x 1 columns]

# %%
df[['Status','Qty',]]  # multiple records
# Out:
#                               Status  Qty
# 0                          Cancelled    0
# 1       Shipped - Delivered to Buyer    1
# 2                            Shipped    1
# 3                          Cancelled    0
# 4                            Shipped    1
# ...                              ...  ...
# 128970                       Shipped    1
# 128971                       Shipped    1
# 128972                       Shipped    1
# 128973                       Shipped    1
# 128974                       Shipped    1
#
# [128975 rows x 2 columns]

# %% [markdown]
# # If 100 features then use list comprehension to pick neccessary features

# %%
#df.columns
df[[col for col in df.columns if col not in ['index','Unnamed: 22','B2B']]]
# Out:
#                    Order ID      Date                        Status  \
# 0       405-8078784-5731545  04-30-22                     Cancelled
# 1       171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2       404-0687676-7273146  04-30-22                       Shipped
# 3       403-9615377-8133951  04-30-22                     Cancelled
# 4       407-1069790-7240320  04-30-22                       Shipped
# ...                     ...       ...                           ...
# 128970  406-6001380-7673107  05-31-22                       Shipped
# 128971  402-9551604-7544318  05-31-22                       Shipped
# 128972  407-9547469-3152358  05-31-22                       Shipped
# 128973  402-6184140-0545956  05-31-22                       Shipped
# 128974  408-7436540-8728312  05-31-22                       Shipped
#
#        Fulfilment Sales Channel  ship-service-level    Style              SKU  \
# ...

# %%
valid_col = [col for col in df.columns if col not in ['index','Unnamed: 22','B2B']]

# %%
df[valid_col]
# Out:
#                    Order ID      Date                        Status  \
# 0       405-8078784-5731545  04-30-22                     Cancelled
# 1       171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2       404-0687676-7273146  04-30-22                       Shipped
# 3       403-9615377-8133951  04-30-22                     Cancelled
# 4       407-1069790-7240320  04-30-22                       Shipped
# ...                     ...       ...                           ...
# 128970  406-6001380-7673107  05-31-22                       Shipped
# 128971  402-9551604-7544318  05-31-22                       Shipped
# 128972  407-9547469-3152358  05-31-22                       Shipped
# 128973  402-6184140-0545956  05-31-22                       Shipped
# 128974  408-7436540-8728312  05-31-22                       Shipped
#
#        Fulfilment Sales Channel  ship-service-level    Style              SKU  \
# ...

# %%
df.Amount
# Out:
# 0          647.62
# 1          406.00
# 2          329.00
# 3          753.33
# 4          574.00
#            ...
# 128970     517.00
# 128971     999.00
# 128972     690.00
# 128973    1199.00
# 128974     696.00
# Name: Amount, Length: 128975, dtype: float64

# %% [markdown]
# # if no space then df.Amount works but df.Sales Channel will not work

# %%
df['Sales Channel ']
# Out:
# 0         Amazon.in
# 1         Amazon.in
# 2         Amazon.in
# 3         Amazon.in
# 4         Amazon.in
#             ...
# 128970    Amazon.in
# 128971    Amazon.in
# 128972    Amazon.in
# 128973    Amazon.in
# 128974    Amazon.in
# Name: Sales Channel , Length: 128975, dtype: object

# %%
strip_coll= [col.strip() for col in df.columns ]

# %%
df.dtypes
# Out:
# index                   int64
# Order ID               object
# Date                   object
# Status                 object
# Fulfilment             object
# Sales Channel          object
# ship-service-level     object
# Style                  object
# SKU                    object
# Category               object
# Size                   object
# ASIN                   object
# Courier Status         object
# Qty                     int64
# currency               object
# Amount                float64
# ship-city              object
# ship-state             object
# ship-postal-code      float64
# ship-country           object
# promotion-ids          object
# B2B                      bool
# fulfilled-by           object
# Unnamed: 22            object
# dtype: object

# %% [markdown]
# # object is refer to string data in pandas

# %%
odj_col = [col for col in df.columns if df[col].dtypes== 'object']

# %%
df[odj_col]  #all string-data
# Out:
#                    Order ID      Date                        Status  \
# 0       405-8078784-5731545  04-30-22                     Cancelled
# 1       171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2       404-0687676-7273146  04-30-22                       Shipped
# 3       403-9615377-8133951  04-30-22                     Cancelled
# 4       407-1069790-7240320  04-30-22                       Shipped
# ...                     ...       ...                           ...
# 128970  406-6001380-7673107  05-31-22                       Shipped
# 128971  402-9551604-7544318  05-31-22                       Shipped
# 128972  407-9547469-3152358  05-31-22                       Shipped
# 128973  402-6184140-0545956  05-31-22                       Shipped
# 128974  408-7436540-8728312  05-31-22                       Shipped
#
#        Fulfilment Sales Channel  ship-service-level    Style              SKU  \
# ...

# %%
[col for col in df.columns if df[col].dtype != 'object']
# Out:
# ['index', 'Qty', 'Amount', 'ship-postal-code', 'B2B']

# %%
df.head(3)
# Out:
#    index             Order ID      Date                        Status  \
# 0      0  405-8078784-5731545  04-30-22                     Cancelled
# 1      1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146  04-30-22                       Shipped
#
#   Fulfilment Sales Channel  ship-service-level    Style              SKU  \
# 0   Merchant      Amazon.in           Standard   SET389   SET389-KR-NP-S
# 1   Merchant      Amazon.in           Standard  JNE3781  JNE3781-KR-XXXL
# 2     Amazon      Amazon.in          Expedited  JNE3371    JNE3371-KR-XL
#
#   Category  ... currency  Amount    ship-city   ship-state ship-postal-code  \
# 0      Set  ...      INR  647.62       MUMBAI  MAHARASHTRA         400081.0
# 1    kurta  ...      INR  406.00    BENGALURU    KARNATAKA         560085.0
# 2    kurta  ...      INR  329.00  NAVI MUMBAI  MAHARASHTRA         410210.0
#
#    ship-country                                      promotion-ids    B2B  \
# ...

# %%
df.tail(2)
# Out:
#          index             Order ID      Date   Status Fulfilment  \
# 128973  128973  402-6184140-0545956  05-31-22  Shipped     Amazon
# 128974  128974  408-7436540-8728312  05-31-22  Shipped     Amazon
#
#        Sales Channel  ship-service-level  Style           SKU Category  ...  \
# 128973      Amazon.in          Expedited  J0012  J0012-SKD-XS      Set  ...
# 128974      Amazon.in          Expedited  J0003   J0003-SET-S      Set  ...
#
#        currency  Amount ship-city    ship-state ship-postal-code  \
# 128973      INR  1199.0     Halol       Gujarat         389350.0
# 128974      INR   696.0    Raipur  CHHATTISGARH         492014.0
#
#         ship-country                                 promotion-ids    B2B  \
# 128973            IN  IN Core Free Shipping 2015/04/08 23-48-5-108  False
# 128974            IN  IN Core Free Shipping 2015/04/08 23-48-5-108  False
#
#         fulfilled-by Unnamed: 22
# 128973           NaN       False
# 128974           NaN       False
#
# ...

# %% [markdown]
# # delete column ↓

# %%
df.drop('Unnamed: 22',axis = 1) #axis = 1 will search in columns & 0 means search in row
# Out:
#          index             Order ID      Date                        Status  \
# 0            0  405-8078784-5731545  04-30-22                     Cancelled
# 1            1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2            2  404-0687676-7273146  04-30-22                       Shipped
# 3            3  403-9615377-8133951  04-30-22                     Cancelled
# 4            4  407-1069790-7240320  04-30-22                       Shipped
# ...        ...                  ...       ...                           ...
# 128970  128970  406-6001380-7673107  05-31-22                       Shipped
# 128971  128971  402-9551604-7544318  05-31-22                       Shipped
# 128972  128972  407-9547469-3152358  05-31-22                       Shipped
# 128973  128973  402-6184140-0545956  05-31-22                       Shipped
# 128974  128974  408-7436540-8728312  05-31-22                       Shipped
#
# ...

# %%
df.drop('Unnamed: 22',axis = 1,inplace = True)
# to delete in same dataframe (df) or store in new (df1)

# %% [markdown]
# # Change feature name↓

# %%
df.rename({'index':'chnaged_index'},axis=1)
# Out:
#         chnaged_index             Order ID      Date  \
# 0                   0  405-8078784-5731545  04-30-22
# 1                   1  171-9198151-1101146  04-30-22
# 2                   2  404-0687676-7273146  04-30-22
# 3                   3  403-9615377-8133951  04-30-22
# 4                   4  407-1069790-7240320  04-30-22
# ...               ...                  ...       ...
# 128970         128970  406-6001380-7673107  05-31-22
# 128971         128971  402-9551604-7544318  05-31-22
# 128972         128972  407-9547469-3152358  05-31-22
# 128973         128973  402-6184140-0545956  05-31-22
# 128974         128974  408-7436540-8728312  05-31-22
#
#                               Status Fulfilment Sales Channel   \
# 0                          Cancelled   Merchant      Amazon.in
# 1       Shipped - Delivered to Buyer   Merchant      Amazon.in
# 2                            Shipped     Amazon      Amazon.in
# 3                          Cancelled   Merchant      Amazon.in
# ...

# %%
df = pd.DataFrame({'num_legs': [2, 4, 8, 0],
                   'num_wings': [2, 0, 0, 0],
                   'num_specimen_seen': [10, 2, 1, 8]},
                  index=['falcon', 'dog', 'spider', 'fish'])

# %%
df
# Out:
#         num_legs  num_wings  num_specimen_seen
# falcon         2          2                 10
# dog            4          0                  2
# spider         8          0                  1
# fish           0          0                  8

# %%
valid_col = ['legs','wings','specimen']      #way to complete change the feature name
df.columns = valid_col

# %%
df
# Out:
#         legs  wings  specimen
# falcon     2      2        10
# dog        4      0         2
# spider     8      0         1
# fish       0      0         8

# %%
df.columns=[col.upper() for col in df.columns]
df.columns=[col.lower() for col in df.columns]
df.columns=[col.strip() for col in df.columns]

# %% [markdown]
# # Add new feature with value

# %%
df['temp']='hello bro'

# %%
df
# Out:
#         num_legs  num_wings  num_specimen_seen       temp
# falcon         2          2                 10  hello bro
# dog            4          0                  2  hello bro
# spider         8          0                  1  hello bro
# fish           0          0                  8  hello bro

# %%
df['num_specimen_seen']='9'

# %%
df
# Out:
#         num_legs  num_wings num_specimen_seen       temp
# falcon         2          2                 9  hello bro
# dog            4          0                 9  hello bro
# spider         8          0                 9  hello bro
# fish           0          0                 9  hello bro
